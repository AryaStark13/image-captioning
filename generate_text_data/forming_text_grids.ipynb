# %%
import ast
import warnings
import re
warnings.filterwarnings("ignore")

# %%
def load_text_data():
    with open("../data/x.txt") as f:
        x_file = f.readlines()

    with open("../data/y.txt") as f:
        y_file = f.readlines()

    x_list = []
    y_list_temp = []

    for x_val, y_val in zip(x_file, y_file):
        x_list.append((x_val.split(", \n")[0]))
        y_list_temp.append((y_val.split(" \n")[0]))

    y_list = []
    for y in y_list_temp:
        x = y
        x = ast.literal_eval(x)
        y_list.append(x)

    x_list_clean = []
    y_list_clean = []

    for x in x_list:
        x = re.sub(r'[^\w\s]', '', x)
        x = x.lower()
        x_list_clean.append(x)

    for y in y_list:
        for i in range(len(y)):
            y[i] = re.sub(r'[^\w\s]', '', y[i])
            y[i] = y[i].lower()
        y_list_clean.append(y)

    return x_list_clean, y_list_clean

x_text, y_text = load_text_data()

# %%
input_list = x_text

output_list = []

for input_str in input_list:
    words_coords = input_str.split()
    words = []
    coords = []
    item=0
    while item < len(words_coords):
        if words_coords[item].isdigit():
            coords.append(int(words_coords[item]))
            item=item+1
        else:
            words.append(words_coords[item])
            if(words_coords[item+1].isalpha()):
                try:
                    words[-1]=words[-1]+ '_' + words_coords[item+1]
                except:
                    print(input_list.index(input_str))


                item=item+2

            else:
                item=item+1
    result = ''
    for i in range(len(words)):
        result += words[i] + ' '
        result += ' '.join(map(str, coords[i*4:(i+1)*4]))
        result += ' '
    output_list.append(result)

# %%
output_list[2:4]
# Out:
# ['car 25 48 36 56 train 76 34 83 44 ', 'stop_sign 32 7 74 63 car 28 84 43 91 ']

# %%
my_list = output_list

for i in range(len(my_list)):
    my_list[i] = my_list[i].strip()

# %%
input_list = my_list
output_list=[]
for input_str in input_list:
# Split the input string into object strings
    object_strs = input_str.split()
    # print(object_strs)

    # Initialize empty lists for the object coordinates
    object_coords = []

    # Iterate over the object strings and extract the coordinates
    for i in range(1, len(object_strs), 5):
        x1, y1, x2, y2 = map(int, object_strs[i:i+4])
        object_coords.append((x1, y1, x2, y2))
    # print(object_coords)    


    output_coords = []
    for x1, y1, x2, y2 in object_coords:
        output_coords.append(( x1 + (x2-x1)/2, y1 + (y2-y1)/2))
    # print(output_coords)
    # Combine the object names and coordinates into the output string
    output_str = ''
    n=len(output_coords)
    # print(n)
    
    for i in range(n):
        
        name = object_strs[i*5]
        # print(name)
        

        coords_str = ' '.join(map(str, output_coords[i]))
        if i == 0:
            output_str += f"{name} {coords_str}"
        else:
            output_str += f" {name} {coords_str}"

    # Print the output string
    output_list.append(output_str)
output_list
# Out:
# ['person 73.0 27.0 person 24.5 19.5 person 12.0 60.5 person 44.5 25.5 person 58.0 65.0 person 48.0 44.5 person 38.5 62.0 person 73.0 34.0 person 22.5 16.5 person 39.0 66.0',
#  'frisbee 48.0 34.0 person 17.0 7.5 person 34.5 13.0 person 69.0 5.0 person 87.0 27.5 frisbee 71.0 19.0 frisbee 16.5 56.0',
#  'car 30.5 52.0 train 79.5 39.0',
#  'stop_sign 53.0 35.0 car 35.5 87.5',
#  'person 70.5 6.0 person 38.0 58.5',
#  'bird 41.0 34.5',
#  'horse 33.0 52.5 person 23.5 6.0 person 91.0 46.5',
#  'pizza 5.0 49.0',
#  'person 30.0 55.0 person 45.5 39.5 person 32.0 40.5 person 23.5 28.5 cell_phone 33.0 39.0',
#  'person 55.0 77.0 person 16.5 78.5 person 9.5 64.5 person 30.5 52.0 person 59.5 54.0 person 84.0 77.5 person 27.5 60.5 person 73.0 68.5',
#  'bed 41.5 55.0 chair 89.0 40.5 dining_table 47.5 77.5',
#  '',
#  'person 37.0 50.5 baseball_bat 64.0 30.0',
#  'couch 5.0 23.0 cat 32.0 30.5',
#  'cat 82.0 19.0 bicycle 13.0 36.0',
#  'giraffe 87.5 44.0 giraffe 6.0 56.0 giraffe 11.0 34.0 giraffe 30.0 42.0',
#  'airplane 43.5 46.5',
#  'car 48.5 88.5 clock 76.0 17.5',
#  'motorcycle 49.5 53.0 person 47.5 36.5',
#  'motorcycle 48.0 18.0 person 67.5 36.0',
#  'motorcycle 47.0 63.0 person 2.5 46.0 person 14.0 46.5 person 40.5 40.0 person 44.0 55.0 person 15.5 46.5 person 53.0 53.0 person 47.0 39.0 person 33.0 23.0',
#  'toilet 28.5 67.5',
#  'cup 88.0 52.5',
#  'car 77.0 35.5 person 27.0 58.5 car 60.5 64.5',
#  'person 50.0 42.5 cake 3.5 42.5 dining_table 50.0 52.0',
#  'person 86.5 53.0',
#  'vase 30.0 51.5 toilet 79.5 59.5 sink 10.5 63.0 sink 53.0 29.0',
#  'cat 55.5 17.0 car 8.5 53.0 bottle 24.0 13.5 car 56.0 66.5',
#  'elephant 20.0 22.0 person 41.0 31.0',
#  'bird 44.5 49.5',
#  'stop_sign 78.5 58.0',
#  'person 49.0 55.0 tennis_racket 63.5 38.5',
#  'zebra 53.0 44.0',
#  'sink 25.0 78.0 sink 6.5 48.0',
#  'bear 34.0 31.0',
#  '',
#  'giraffe 36.5 56.5',
#  'tv 46.0 77.0',
#  'broccoli 5.5 49.5 broccoli 58.5 32.5 carrot 46.0 55.5 broccoli 69.5 68.5 carrot 40.5 74.5',
#  '',
#  'toilet 44.0 9.5',
#  'bowl 42.0 43.0 broccoli 70.0 24.0',
#  'toilet 56.0 82.0 sink 35.0 67.0',
#  'cow 31.0 62.0 person 46.5 55.5 person 70.0 50.0 person 78.5 35.5 person 30.5 5.5 person 5.5 57.0 person 2.0 56.5',
#  '',
#  'clock 23.0 28.0 clock 47.5 29.0',
#  '',
#  'fire_hydrant 32.0 55.5 person 87.5 41.5 person 69.5 45.0 car 10.5 39.0',
#  'car 11.5 48.5',
#  'bus 51.5 45.5',
#  'couch 52.5 48.0 cup 75.5 56.0 couch 46.5 34.5',
#  'sandwich 38.5 18.5',
#  'train 30.5 57.0',
#  'teddy_bear 66.0 49.0',
#  'cat 25.5 37.5',
#  'clock 50.0 42.0',
#  'person 52.0 23.0 elephant 35.5 7.0',
#  'bird 37.5 59.0',
#  'person 41.5 51.5 sports_ball 46.0 36.0',
#  'person 79.5 5.0 person 49.5 48.5 person 64.5 49.0 dining_table 32.0 41.5 couch 22.0 63.0',
#  '',
#  'person 85.0 58.0 skis 75.0 47.5',
#  'person 41.0 38.0 umbrella 76.0 19.5 person 46.0 29.0 person 71.0 27.0 person 27.5 26.5 person 10.0 28.5 dog 42.0 61.5 umbrella 23.5 11.5',
#  'person 66.5 3.5 person 26.5 61.0',
#  '',
#  'person 55.0 57.0 baseball_glove 71.0 57.5',
#  'elephant 55.0 81.5 elephant 1.0 57.5',
#  'person 15.5 49.5',
#  'cat 56.0 54.0',
#  'bottle 40.0 2.5 person 17.0 25.5 cup 75.5 45.5 bottle 42.5 19.0',
#  'train 41.0 43.5',
#  'person 15.5 48.0',
#  'person 59.0 85.0 person 54.0 84.5 surfboard 34.5 85.0',
#  'elephant 63.5 44.5 elephant 35.5 22.5',
#  '',
#  'person 20.5 49.5 person 74.5 51.5 person 44.0 60.5',
#  'person 7.0 49.5 remote 59.0 35.5',
#  'traffic_light 17.5 61.0 traffic_light 12.0 71.5 traffic_light 21.0 63.0',
#  'toilet 27.0 79.5',
#  'donut 23.0 74.0 donut 42.5 71.0 donut 31.5 41.5',
#  'teddy_bear 33.0 59.5',
#  'person 40.5 38.0 person 32.5 22.5 truck 77.5 50.0 person 10.0 58.0 person 7.5 55.0 person 25.5 48.5 person 20.5 47.0',
#  '',
#  'bed 14.0 27.0',
#  'microwave 42.0 13.0 oven 38.0 22.5',
#  'person 9.0 61.5',
#  'toilet 18.5 82.5 person 22.5 27.0 person 3.5 39.0',
#  'zebra 15.0 58.0 zebra 14.0 67.0 zebra 90.5 60.0',
#  'traffic_light 71.0 38.5',
#  'airplane 50.0 61.5',
#  'person 20.5 50.0 person 2.5 44.5',
#  'person 68.0 57.0 person 32.0 50.0',
#  'elephant 53.0 56.5 elephant 9.5 36.0 elephant 51.5 4.0',
#  'airplane 5.5 49.0',
#  'truck 33.0 51.0',
#  'sink 5.5 68.5',
#  'bear 46.5 5.0',
#  'orange 47.5 64.5 orange 88.0 77.0 orange 67.5 76.0 bowl 39.0 69.0 vase 46.5 43.5',
#  'car 34.5 11.0',
#  'car 49.5 78.0',
#  'clock 55.0 29.5',
#  'person 33.5 25.0 person 42.0 72.5 skateboard 46.5 87.0 skateboard 32.0 44.0',
#  'stop_sign 45.5 42.5',
#  'bicycle 61.5 49.5 person 46.5 42.0 motorcycle 14.0 57.5 person 7.5 36.5 bicycle 11.0 39.0',
#  '',
#  'sink 39.5 50.5 sink 15.0 31.0',
#  'person 52.0 42.5 car 69.5 40.5 car 30.5 84.0 person 5.0 35.0 car 23.0 36.5 car 30.5 18.5 traffic_light 28.5 9.0 bicycle 90.0 41.5',
#  'person 50.5 31.5 skateboard 20.0 67.5',
#  'person 3.5 27.5 bottle 43.0 37.5 tennis_racket 31.0 23.5',
#  'bench 48.0 31.5',
#  'suitcase 54.5 59.0',
#  'giraffe 45.0 52.0 giraffe 9.5 25.0',
#  'cat 40.0 61.0 laptop 8.0 38.0',
#  'cell_phone 10.0 53.0 person 24.5 45.0',
#  '',
#  'dog 61.0 13.5 horse 16.5 49.0 person 31.0 41.5',
#  'zebra 56.0 52.0',
#  'teddy_bear 33.0 4.5 teddy_bear 63.5 47.5',
#  'banana 33.5 45.0 apple 71.5 50.5 apple 72.5 59.5 apple 75.5 78.0 apple 65.0 77.5',
#  'person 75.5 39.5 pizza 64.0 76.5 person 47.0 38.0 bottle 16.0 39.5 pizza 25.0 42.5 pizza 18.5 34.5 knife 9.5 52.5 person 46.0 44.0 cup 35.0 62.0 cup 25.0 58.5',
#  'clock 55.0 19.0',
#  'person 55.5 27.0',
#  'motorcycle 13.0 71.5',
#  'banana 56.0 46.5',
#  'person 81.5 63.0 bus 26.5 32.0 person 62.5 39.0 bus 11.5 30.5 person 7.5 41.5 person 96.5 4.0 person 4.0 27.0 person 33.5 40.0',
#  'person 36.0 42.5 person 50.0 42.0 person 6.0 49.5 person 12.5 51.5 person 69.5 87.5 person 51.0 51.0 person 3.0 51.0 person 37.5 48.0 person 85.0 49.5',
#  'person 17.5 21.0 person 10.0 27.5 person 14.0 22.5 person 61.5 6.0',
#  'train 10.0 49.0',
#  'suitcase 45.5 56.0 suitcase 3.5 7.0 chair 84.5 23.5 person 40.5 5.5 suitcase 64.0 70.0',
#  'person 37.0 50.5 person 47.5 33.5 person 82.0 78.0 potted_plant 38.5 35.5 person 19.0 55.0 book 5.5 88.5 couch 59.0 25.5',
#  'laptop 37.5 8.5 cat 39.5 33.0',
#  'person 57.5 35.5 surfboard 14.0 64.5',
#  'car 30.5 82.0 car 70.0 80.0 car 36.0 81.0 car 31.0 79.5 traffic_light 38.0 22.5 traffic_light 44.0 22.0',
#  'person 8.5 48.5 person 54.5 21.5 kite 9.0 27.5',
#  '',
#  'knife 36.0 52.0 carrot 30.5 49.0',
#  'pizza 12.5 52.5 wine_glass 52.0 16.0 bottle 39.0 15.5 bottle 52.0 9.5 bottle 59.5 14.0 bottle 82.5 30.5 cup 50.5 23.0 cup 39.0 24.5',
#  'bowl 51.5 38.0 dining_table 50.5 52.5',
#  'boat 32.5 34.5 person 43.5 54.5',
#  '',
#  'zebra 28.0 6.0 zebra 30.5 14.5',
#  'cat 47.0 50.0 bed 45.5 49.5',
#  'suitcase 29.0 36.5 person 27.0 13.0 person 8.5 40.0 handbag 70.5 66.0',
#  'person 44.5 49.5',
#  'bear 79.0 75.5',
#  'person 26.0 50.5 cake 24.5 76.5 dining_table 36.5 71.0',
#  'person 21.5 76.5 person 37.0 28.0 person 48.5 53.0 person 54.5 35.0 person 10.5 26.5 person 9.5 48.0 person 71.5 35.5 person 77.5 54.0 person 62.0 50.0 person 68.0 29.0',
#  'dog 24.0 36.5 person 6.5 57.0',
#  'zebra 19.0 56.5 zebra 24.0 57.0 zebra 83.0 59.5',
#  'person 64.5 41.0',
#  'person 37.0 68.5',
#  'person 44.0 44.5 tennis_racket 34.0 62.5',
#  'person 24.5 55.5 bottle 67.5 64.0 cat 8.5 28.0 bottle 60.5 61.0',
#  'toilet 30.0 33.0',
#  '',
#  'horse 29.5 55.5 horse 50.0 51.0',
#  'sandwich 46.5 40.5 person 22.5 54.0',
#  '',
#  'cat 52.5 66.5',
#  'cow 59.5 5.0',
#  'person 61.0 58.0 skis 31.0 84.5',
#  'cow 85.5 59.0 cow 61.5 50.5 cow 92.5 55.5 cow 89.5 55.0',
#  'person 54.5 61.5 person 13.0 29.5 person 52.0 15.5',
#  'cat 56.5 52.0 tv 8.5 26.0 cat 53.0 58.5',
#  'laptop 56.5 49.0 person 4.5 33.5',
#  'person 41.0 66.0 person 46.5 74.0 person 80.0 78.0 sports_ball 48.0 23.0 baseball_glove 36.5 69.0',
#  'banana 5.0 5.0 orange 43.5 49.5 apple 76.0 27.5 orange 24.5 24.5',
#  'person 61.0 65.0 bicycle 36.5 61.0',
#  'elephant 23.5 90.5 elephant 43.0 88.0 elephant 81.0 49.5 elephant 52.5 8.5 person 13.0 78.0 person 98.0 78.0 person 57.5 42.0 person 25.5 78.0 person 45.0 76.5',
#  'cake 31.0 31.5 fork 8.0 62.0 cake 47.5 48.5',
#  'laptop 25.0 29.5',
#  'person 54.0 50.5 car 25.0 15.5 car 19.0 17.0',
#  'person 32.5 50.0 person 84.0 26.5 tennis_racket 70.5 48.0 person 51.5 2.5',
#  'person 51.5 15.5 person 75.5 20.0 person 70.0 28.5',
#  'clock 22.0 31.5',
#  'clock 63.5 37.0',
#  'sheep 58.5 41.5',
#  'cup 27.0 8.0 bottle 23.0 74.5 cup 66.0 20.5',
#  'cup 41.5 17.0 bottle 13.5 21.0 sandwich 36.5 46.5 bowl 29.5 50.0 dining_table 5.0 52.0',
#  'person 18.5 48.5 horse 22.0 66.0 person 39.5 48.5 person 64.0 45.5',
#  '',
#  'person 80.0 62.0 person 16.5 34.0 person 5.0 63.5 person 29.5 17.0 person 8.0 59.5 person 64.0 20.0',
#  'horse 66.5 56.0 person 13.0 59.5 person 40.5 36.0',
#  'umbrella 62.0 32.0 person 44.0 4.5 person 13.0 7.5 person 61.0 60.5 person 63.5 0.5 person 52.0 4.5',
#  '',
#  'bench 20.0 35.0 bench 20.0 67.5 car 80.0 45.5',
#  'tv 31.0 8.0',
#  'bird 62.0 18.0',
#  'person 35.0 43.0 surfboard 62.0 70.0',
#  'person 44.0 53.5 person 16.0 57.5 person 59.5 12.5 person 75.5 12.0 tennis_racket 58.0 75.5 person 20.5 12.5',
#  'umbrella 56.0 29.0 person 33.5 50.0',
#  'car 59.0 73.0 car 15.0 71.0 person 18.0 69.0 person 3.5 41.0 car 40.0 68.0 motorcycle 10.0 74.5',
#  'person 17.5 50.5 person 45.5 52.0 skateboard 26.0 58.0',
#  'bus 47.5 50.0',
#  'person 59.0 45.0',
#  'stop_sign 59.0 28.0',
#  'person 22.5 48.0',
#  'bird 45.5 68.0 bird 11.5 64.5',
#  'person 20.0 39.5 person 30.0 61.5 person 24.5 26.0 person 77.0 70.0 person 86.0 36.0 person 14.5 24.0 person 72.5 49.5 person 38.5 35.0 person 9.5 8.5 cup 32.0 34.5 person 56.0 39.5',
#  'zebra 39.0 50.5',
#  'truck 38.5 45.5',
#  'person 9.5 15.0 person 79.0 69.5 baseball_glove 40.5 64.0 person 24.0 71.0 baseball_bat 41.0 26.0',
#  'pizza 50.0 49.0 broccoli 13.5 44.0 broccoli 29.0 19.0 broccoli 42.5 17.0',
#  'person 40.5 58.5',
#  'bird 17.5 15.5 bird 31.0 15.5 bird 54.5 50.0',
#  'person 30.5 3.0 person 37.0 31.0 person 71.5 65.5 person 67.0 37.5 person 46.0 13.5 dining_table 26.5 44.0 book 53.0 48.5',
#  'train 70.5 53.5',
#  'person 64.5 55.5',
#  'cow 45.5 49.0',
#  'chair 15.0 33.5 couch 46.0 40.5 suitcase 50.5 48.5',
#  'bus 45.0 70.5 car 9.5 86.0 car 80.5 40.5 car 14.0 46.5 car 88.5 77.0 car 4.0 78.5 car 69.0 45.0 traffic_light 84.0 35.0 car 76.0 76.0',
#  'zebra 59.5 54.5',
#  'teddy_bear 51.5 51.0 book 70.0 28.0 teddy_bear 29.5 61.0 book 87.0 28.0 teddy_bear 17.0 21.0 teddy_bear 51.5 69.5',
#  'cow 37.0 65.5 cow 31.0 64.5',
#  'person 20.5 28.0 person 84.0 4.5 chair 10.5 54.0 dining_table 35.5 83.0 person 47.0 48.5 chair 68.5 60.5',
#  'zebra 10.5 6.0',
#  '',
#  'person 58.0 33.0',
#  'dog 20.0 61.0 dog 8.0 2.5',
#  'person 56.0 41.5 skateboard 33.5 82.0',
#  'clock 13.0 29.0 bicycle 64.5 46.5 person 64.5 85.0 truck 48.5 77.5 person 12.0 82.0 person 4.5 82.5 bus 13.0 78.0 person 15.0 82.5',
#  'cup 85.5 45.5 cup 37.5 43.0 pizza 42.0 8.0 cup 83.5 22.0 cup 61.0 10.5 dining_table 5.0 15.5 pizza 35.0 31.5 pizza 36.5 30.5 pizza 35.5 19.5 pizza 35.5 23.0 person 23.5 13.0',
#  'potted_plant 92.0 49.5 chair 55.0 55.5 couch 23.5 29.0 potted_plant 73.0 47.5',
#  'bear 29.5 56.0 cow 27.0 66.0',
#  'cat 13.0 7.0',
#  'person 45.5 50.5 person 14.5 51.0 person 63.5 55.0 banana 33.0 41.0 person 34.5 61.0 banana 40.0 46.5',
#  '',
#  'bird 22.5 27.5 boat 51.5 48.5 person 90.0 78.0 person 45.0 76.5 person 93.5 76.5',
#  '',
#  'person 50.0 53.5 tennis_racket 31.5 43.5 person 4.0 22.5 person 68.0 13.0 person 33.5 12.5',
#  'elephant 51.5 51.5 elephant 38.0 46.0',
#  'person 17.0 27.0 person 8.0 49.0 person 27.0 25.5',
#  'person 21.5 67.5 person 53.5 56.5 person 91.5 24.0 person 66.5 27.5 person 71.0 30.5 person 15.5 21.0 baseball_glove 33.5 58.5 person 39.0 30.5',
#  'stop_sign 51.5 52.5 car 66.0 69.0 car 18.0 64.5 car 24.5 62.0 car 52.5 67.0 car 68.0 62.0 car 4.5 39.0 car 9.0 64.0',
#  'banana 25.5 8.5 remote 74.5 40.5',
#  'person 86.0 33.5 person 47.0 80.0 person 69.0 75.5 person 5.5 36.5 person 16.0 76.5 person 40.5 22.0 person 32.0 36.5 person 62.0 39.5 person 47.5 32.5 person 0.5 49.5 person 51.0 51.5',
#  'person 68.0 58.5 person 44.5 14.5 handbag 85.0 69.0 person 2.0 58.0 person 8.0 36.0',
#  'car 28.5 90.0 car 10.0 83.0 car 1.5 75.0 person 6.0 48.5',
#  'bird 41.5 23.5',
#  'potted_plant 41.0 31.0 refrigerator 7.5 72.0 oven 24.0 76.0',
#  'person 38.0 51.5 person 40.0 45.5 frisbee 71.5 11.5',
#  'person 45.5 9.0 person 11.0 9.0 person 49.0 55.0 person 70.0 9.0',
#  'person 55.0 20.0 person 35.5 16.0 bowl 44.5 77.0 cup 35.5 28.5 person 28.5 25.5 cup 11.5 58.0 dining_table 5.0 6.5 person 11.5 33.5 wine_glass 42.5 36.5 bottle 76.5 30.5 cup 91.5 52.5',
#  'pizza 5.0 52.5',
#  'person 28.0 19.5 horse 2.5 51.5 person 65.0 60.0',
#  'bowl 50.0 52.5',
#  'surfboard 46.5 43.0 surfboard 3.0 48.5 surfboard 60.5 42.0 surfboard 72.5 41.0 surfboard 10.5 48.5 surfboard 52.5 43.0 surfboard 93.0 37.0 surfboard 8.5 44.0 surfboard 78.0 43.0',
#  'person 44.0 50.5 sports_ball 82.0 61.5',
#  '',
#  'person 39.0 42.5 suitcase 45.0 62.0',
#  'bear 29.0 49.0 bear 29.0 57.0',
#  'person 26.0 54.5 tv 65.5 33.0',
#  'bus 45.5 13.0 car 11.0 22.0',
#  'person 22.0 36.5',
#  'couch 60.0 60.5 tv 52.0 64.5 chair 24.0 67.0 couch 24.0 67.0',
#  'person 33.0 68.5 person 46.5 63.5 person 41.0 64.0 person 97.0 58.5 bus 30.5 52.5 person 94.5 60.0 person 51.0 60.0',
#  'person 11.5 19.5 person 45.0 18.5 cake 43.5 80.0 cake 57.5 81.0 cup 24.0 7.0 cake 71.0 55.0',
#  'orange 6.0 83.0 orange 50.5 41.0 orange 66.0 63.0 orange 43.0 41.5',
#  'person 55.5 50.5 frisbee 20.0 76.5',
#  '',
#  'kite 30.5 10.5 surfboard 50.0 48.5 person 28.5 78.0 person 19.5 54.0',
#  'person 55.0 21.5 skateboard 42.5 25.5',
#  'person 20.5 53.5 person 54.5 51.5 person 77.5 56.5',
#  'zebra 82.5 60.0 zebra 29.0 58.5 zebra 77.0 57.5 zebra 19.0 59.0 zebra 41.5 58.0 zebra 55.0 58.0 zebra 46.5 61.0',
#  'parking_meter 23.5 48.5 parking_meter 8.5 26.0',
#  '',
#  'bench 66.5 87.0 train 5.0 52.0',
#  'toilet 42.5 77.5',
#  'cow 88.0 63.5 cow 57.5 63.0 horse 9.0 61.5 cow 41.5 36.5 cow 19.5 64.0 horse 13.0 60.0',
#  'person 38.5 21.5 person 42.0 51.5 person 49.5 12.0',
#  'person 49.5 7.0',
#  'person 43.5 59.5 sheep 59.5 87.0 sheep 81.0 53.0 sheep 89.5 91.0 sheep 72.0 86.5 sheep 66.5 86.5',
#  'person 46.0 32.5',
#  'person 51.5 49.0 person 35.0 45.5 person 38.5 54.0 baseball_bat 48.5 20.0 baseball_glove 29.5 57.0',
#  'dining_table 5.0 43.5',
#  'car 53.5 90.0 bicycle 43.0 50.5',
#  'clock 77.0 32.0',
#  'train 46.5 51.5',
#  'baseball_glove 53.0 34.0 person 65.0 49.5',
#  'person 50.5 22.0 kite 25.0 27.5',
#  'person 36.0 17.0 giraffe 70.5 33.5',
#  'carrot 78.0 48.0 carrot 52.5 24.5',
#  'person 44.0 64.5 person 61.5 66.0 person 40.5 30.5 person 15.5 63.0 person 52.0 75.0 person 16.0 63.5 car 5.0 62.0 frisbee 60.5 29.5 person 72.0 63.5 person 83.5 64.0',
#  'person 27.0 10.5 person 54.0 12.0 person 16.0 19.5 person 52.0 19.5',
#  'cat 30.0 22.5 tv 52.0 58.0',
#  'laptop 28.0 28.5 tv 14.5 44.0 mouse 44.0 78.0 cup 31.0 44.0 keyboard 53.5 70.0 cup 38.0 43.5 chair 78.0 40.5',
#  'cat 21.0 50.0',
#  'pizza 5.0 5.0',
#  'airplane 56.0 67.5',
#  'clock 46.5 49.0',
#  'person 9.5 5.0 tie 46.0 32.5',
#  'person 47.0 36.5',
#  'person 72.5 55.0 motorcycle 17.5 47.0',
#  'tie 56.5 55.5 cat 55.5 49.5',
#  'skateboard 33.5 74.0 person 48.5 46.5',
#  'dining_table 5.0 5.5 broccoli 68.0 17.5 broccoli 43.5 41.0 bowl 32.5 27.5',
#  'bottle 31.0 23.5 bottle 69.5 12.0 bottle 21.5 19.5 bottle 57.0 12.0',
#  'vase 30.0 20.0 vase 62.5 69.0',
#  'horse 67.5 56.0 horse 41.5 39.0 person 15.0 57.5',
#  'person 15.0 49.0 person 82.5 51.0 person 62.0 58.5 sports_ball 56.5 30.5 person 53.0 46.5',
#  'person 3.5 50.0 person 82.0 8.0 bottle 25.0 56.5',
#  'bear 46.5 5.0',
#  'person 46.0 37.0 skateboard 44.0 51.5',
#  'person 55.0 54.5 person 74.0 34.5 elephant 58.0 71.0 person 18.0 46.5',
#  'frisbee 24.0 60.5 frisbee 40.0 64.0 frisbee 32.0 55.5 frisbee 22.5 51.5 person 33.5 65.0 person 21.0 14.0 person 41.0 60.0 person 55.5 44.5',
#  'person 28.0 49.5 person 33.0 50.0',
#  'train 10.5 67.0',
#  'traffic_light 41.5 26.0 traffic_light 26.0 37.5 traffic_light 70.0 24.0',
#  '',
#  'person 18.0 44.5 person 3.5 12.0 person 20.0 16.0 person 68.0 17.0 person 15.0 12.0 backpack 31.0 46.5 tennis_racket 39.5 68.5 person 9.5 12.0 person 75.0 12.0',
#  'person 45.0 6.5',
#  'person 62.5 50.0 tennis_racket 38.5 82.5',
#  'airplane 5.5 50.0',
#  'person 3.5 73.0 train 44.5 35.5',
#  'elephant 14.5 51.0',
#  'bench 68.0 85.0 boat 43.5 53.5',
#  'cow 44.0 58.5 cow 10.0 49.0',
#  'bus 56.0 43.5 traffic_light 7.5 35.0 person 6.5 31.5 person 7.5 57.5 person 17.5 57.0',
#  'person 65.0 59.5 person 9.0 59.0 person 50.5 49.5 person 6.5 68.5 person 38.5 38.0 person 52.5 58.0 person 46.0 49.5 person 90.5 57.5 person 40.0 58.0 person 37.5 37.0 person 28.5 38.0 baseball_glove 75.0 52.5',
#  'horse 82.5 61.5 cow 23.5 29.5',
#  'cat 21.5 16.5',
#  'laptop 39.0 60.5 bed 49.5 48.0',
#  'kite 88.0 17.0 person 5.0 81.5 person 2.0 81.0 person 9.0 53.0 person 34.0 81.0',
#  'giraffe 47.5 51.5',
#  'train 6.5 6.0',
#  'person 10.0 80.5',
#  'bed 49.5 71.0 cat 54.0 56.5',
#  'airplane 40.0 45.0 person 93.0 74.5',
#  '',
#  'car 5.5 41.5 parking_meter 20.0 59.5 car 52.0 22.0 person 50.5 42.0 car 7.5 37.5',
#  'person 41.0 3.5 person 72.5 17.5 bench 39.5 30.5 skateboard 82.0 54.0',
#  'refrigerator 51.0 33.5 toaster 23.0 85.0',
#  'sports_ball 69.5 70.5 person 79.0 40.0',
#  'bicycle 28.0 57.5',
#  'airplane 57.0 52.5 airplane 41.0 42.5 airplane 44.0 43.0',
#  'chair 72.5 62.5 laptop 37.5 52.5 keyboard 57.5 44.5 tv 49.0 21.5 cup 60.5 35.5',
#  'clock 4.5 20.5 clock 29.0 20.5',
#  'train 42.0 54.5 train 49.0 58.5',
#  'cake 44.5 51.5',
#  'sink 58.5 92.5',
#  'person 23.0 69.5',
#  'vase 36.0 31.5 chair 19.0 81.0 dining_table 36.5 78.5 potted_plant 44.0 56.5 refrigerator 9.5 57.5 chair 54.5 33.5 potted_plant 72.5 18.0',
#  'oven 50.0 59.0',
#  'laptop 18.5 84.5 person 41.5 28.0 chair 82.0 51.5 laptop 23.0 29.5 person 70.0 17.0 chair 55.0 29.5 person 59.0 36.5 chair 67.0 52.0 cup 8.5 93.0 dining_table 74.0 45.0',
#  'laptop 53.0 27.0 cup 76.0 69.5 cup 70.5 70.5',
#  'person 2.5 56.0 bowl 38.5 80.0 person 30.0 26.0',
#  'person 38.5 55.5 person 6.5 57.5 motorcycle 64.0 48.5 motorcycle 40.0 64.0 person 72.5 28.0',
#  'bowl 51.0 50.5',
#  'person 31.5 58.5 person 36.5 62.5 person 50.5 83.0',
#  '',
#  'person 79.5 51.0 person 46.0 60.5 umbrella 36.0 16.0 motorcycle 7.0 39.0 pizza 58.0 70.5 potted_plant 68.0 72.0',
#  'person 66.5 10.0 person 26.0 14.5 person 46.0 45.0 person 32.0 43.0 bottle 82.0 55.0 bottle 85.0 28.5 couch 32.5 57.0',
#  'person 25.5 66.5',
#  'cow 26.5 28.0',
#  'train 41.5 53.5 car 25.0 68.5 train 45.5 47.0',
#  'person 44.5 68.0 kite 20.5 45.5',
#  'airplane 43.0 25.0',
#  'person 5.0 5.5 orange 46.0 67.0',
#  'pizza 10.0 57.0 dining_table 5.0 49.0',
#  'frisbee 37.0 20.5 dog 61.0 50.0',
#  'fire_hydrant 49.5 18.0',
#  'bicycle 25.0 82.0 person 49.5 39.0 person 34.5 81.5 person 25.0 76.0 car 63.0 70.0 potted_plant 2.0 70.5 car 70.0 70.5',
#  'sink 46.0 26.0 toilet 81.0 38.0',
#  'oven 5.5 5.0 cake 49.5 64.0',
#  'dining_table 50.0 44.5 orange 63.5 18.0',
#  'bus 54.0 56.5 person 11.0 70.5 person 7.0 40.5 person 33.0 49.0',
#  'tv 12.5 50.5 chair 50.5 62.5 person 69.0 22.0 chair 62.5 62.0',
#  'person 15.0 62.5 tv 72.0 19.5',
#  'person 65.5 56.0 person 16.5 61.5 person 43.5 45.5 person 91.0 36.5 person 13.0 31.5 person 47.0 34.5 person 30.5 22.0 person 56.5 31.5',
#  'tv 58.0 41.0 couch 14.5 59.5 chair 43.0 70.0 chair 79.0 41.0 chair 69.5 72.0 vase 34.5 81.5 dining_table 63.5 88.0',
#  'cake 53.0 54.0 banana 20.0 44.0',
#  'tv 38.0 35.0 chair 86.0 70.0 chair 7.0 36.0 couch 4.5 80.0 book 41.0 60.5',
#  'airplane 51.0 47.5',
#  'dog 38.0 47.5 frisbee 74.5 81.5',
#  '',
#  'suitcase 70.5 79.0',
#  'dining_table 51.5 38.0 chair 79.5 50.0 bottle 10.5 48.5 vase 51.0 80.0 chair 22.0 73.5 chair 47.0 40.5',
#  'person 84.0 27.5 bus 4.5 43.0 person 3.5 45.0',
#  'horse 58.5 55.0 person 53.0 10.0',
#  'horse 28.5 66.5 person 76.0 50.0',
#  'refrigerator 13.0 67.0',
#  '',
#  'vase 53.0 74.0',
#  'fire_hydrant 41.5 31.0 person 85.5 7.0 person 39.5 50.0 person 18.0 57.0',
#  'sheep 66.0 34.0 sheep 83.5 67.0 sheep 35.0 67.0 person 29.0 57.0',
#  'person 59.5 55.5 person 81.0 55.0 person 33.0 57.5 cake 82.5 47.5 cake 67.5 51.5',
#  'clock 20.5 22.0',
#  'kite 34.0 73.5 kite 47.5 70.0 kite 57.5 38.5 kite 41.0 54.5 person 42.5 44.0',
#  'clock 19.0 44.5',
#  'pizza 48.0 36.5 cup 38.5 41.5 person 49.5 45.5 cup 9.5 63.0 dining_table 5.0 38.0 person 78.5 33.0 cup 7.5 37.5',
#  'broccoli 47.0 21.0 carrot 41.5 10.5',
#  'car 72.5 68.5 car 89.0 67.0',
#  'motorcycle 59.5 76.0',
#  'pizza 49.0 59.5 bottle 44.5 19.5 bowl 7.5 7.0 dining_table 48.5 14.5 person 47.5 12.0',
#  'pizza 52.0 47.5',
#  'person 15.5 66.5 person 63.0 46.0 person 35.0 67.5 person 28.5 44.0 person 10.5 67.5 person 78.5 67.0 person 69.5 66.5 person 93.0 57.5 person 41.5 44.0 person 30.0 68.0 person 50.5 58.0 person 50.0 65.0 person 53.0 72.0 person 73.5 28.5',
#  'laptop 51.0 63.0 person 59.0 42.0',
#  'person 6.0 62.5 person 17.5 21.5 person 22.5 36.0 person 80.5 54.5 person 48.0 5.0 motorcycle 65.0 49.5 bicycle 35.5 66.0 person 15.0 55.0',
#  'car 42.0 84.0 bus 9.5 74.5 car 68.5 80.5 car 77.0 80.0 car 58.5 82.5',
#  'bowl 43.5 56.5',
#  'car 73.0 71.0',
#  'person 69.5 50.5 bowl 20.5 88.0 cup 29.5 49.5 cup 39.5 73.5',
#  'person 30.0 61.0 person 68.5 54.5',
#  'person 38.5 35.0 person 58.5 59.0 surfboard 34.0 47.5 person 74.5 37.0 person 26.5 41.0',
#  'person 87.0 8.0 kite 37.5 19.0 person 80.5 8.0 person 53.5 37.0 kite 45.5 72.5',
#  'person 31.0 59.0 motorcycle 20.5 72.5 motorcycle 42.5 60.0',
#  'person 48.5 51.5 person 89.0 75.0 person 27.5 69.0 tennis_racket 30.0 52.5 person 62.0 31.0 person 53.0 32.0',
#  'train 19.0 73.0',
#  'bus 49.5 6.5',
#  'umbrella 71.0 34.5 person 19.5 71.5 person 51.0 67.5 person 8.0 43.0 person 47.0 39.5 person 7.0 20.5 person 84.0 74.0 person 57.5 69.5 person 18.0 20.5 person 41.0 25.5',
#  '',
#  'person 38.0 5.0 person 54.0 32.5 person 26.0 55.0',
#  'airplane 42.5 66.5',
#  'motorcycle 48.0 46.5 person 52.0 11.0 person 85.0 36.0',
#  'person 50.0 37.5 bicycle 49.0 69.5 car 82.5 29.5 car 32.0 22.5',
#  'person 86.0 48.5 person 52.5 1.5 person 9.0 17.0 person 72.0 46.5 person 28.0 21.5 person 44.5 22.0 kite 52.5 43.0 person 60.5 1.5 person 31.5 21.0 person 56.5 18.0',
#  'car 34.5 80.5 traffic_light 44.5 31.5',
#  'train 47.5 5.5 person 45.0 67.5 person 5.0 56.5',
#  'person 37.0 38.5',
#  'toilet 23.5 41.0 cup 48.5 22.5',
#  'boat 81.0 49.0',
#  'person 53.5 18.5 remote 19.0 71.5',
#  'teddy_bear 46.5 33.5 person 10.5 74.5',
#  'clock 45.0 60.5',
#  'person 77.0 18.0 person 60.5 24.5 person 15.5 23.5',
#  'motorcycle 57.5 54.0 person 57.5 42.5 person 42.5 22.0 person 82.0 21.5',
#  'person 24.0 64.0 skateboard 49.5 44.0',
#  'dog 49.5 36.0',
#  'person 15.5 6.0 person 2.0 15.5 bottle 77.5 19.5',
#  'person 64.0 11.0 person 35.5 56.0 cake 25.5 51.5 dining_table 3.5 76.0 person 48.5 28.5',
#  'chair 63.0 71.0 umbrella 69.0 41.5',
#  'person 40.0 28.0 person 21.0 38.5 pizza 71.0 29.0 pizza 6.0 63.0 bowl 9.5 46.5 bottle 89.0 22.5',
#  'wine_glass 15.5 51.0 bottle 37.0 33.0 pizza 49.5 30.5',
#  '',
#  'person 54.0 31.5 motorcycle 46.0 55.5 person 40.0 18.5 person 8.0 15.0 person 29.5 10.5 person 1.5 13.5 person 87.5 14.0 car 50.5 9.5 person 9.0 14.5 person 71.0 8.5',
#  'train 53.5 17.5 person 3.0 56.5 person 9.5 55.0',
#  'person 8.5 76.5 person 49.5 60.5 skateboard 51.5 80.0',
#  'cake 8.0 13.5 dining_table 49.5 49.5',
#  'car 11.5 62.0 car 15.5 48.5 bus 55.5 52.5 car 52.0 30.0',
#  'fire_hydrant 49.5 12.5 truck 19.5 22.5 truck 26.0 19.5',
#  'laptop 10.0 72.5 person 32.0 5.5 laptop 32.0 72.0 chair 26.0 29.0',
#  '',
#  'toilet 44.5 51.0',
#  'bus 15.0 47.0 car 36.0 56.0 car 17.0 55.5 car 89.0 51.5',
#  'person 8.0 31.0 person 31.5 16.5 person 16.5 53.5 cell_phone 57.0 41.0',
#  'person 48.0 14.0 person 7.0 39.5 person 37.0 17.5 person 12.5 50.5 person 19.0 60.5',
#  'truck 32.0 50.0 truck 73.0 51.5',
#  '',
#  'bus 34.5 45.5 person 47.5 83.0 person 44.5 71.0 person 28.5 53.5 person 7.0 60.5 person 76.0 69.0 person 70.0 65.0',
#  'laptop 22.0 55.5 keyboard 64.5 68.5 tv 65.5 34.5 mouse 53.5 73.0 tv 91.0 55.0',
#  'person 5.5 5.0 person 11.0 26.0',
#  'apple 55.0 30.0',
#  'truck 53.5 40.5 truck 19.5 44.5 truck 91.5 31.0',
#  '',
#  'person 18.5 41.5 surfboard 14.5 55.5',
#  'zebra 58.5 46.0',
#  'elephant 50.5 44.5 cow 5.0 43.5',
#  'donut 22.5 62.0 donut 2.5 39.5 donut 77.0 31.0 donut 82.0 69.5 donut 50.5 30.0 donut 24.5 76.5',
#  'person 86.5 38.5 person 71.5 43.5',
#  'person 42.5 57.5',
#  'tv 30.0 33.5 mouse 82.0 81.0 keyboard 45.5 87.5 bottle 55.0 65.5 mouse 92.5 84.5',
#  'person 47.0 41.5 skateboard 42.5 70.0 person 15.5 35.0 person 46.0 36.5',
#  'motorcycle 44.0 76.0',
#  'person 37.5 2.0 dog 44.5 54.5',
#  '',
#  'person 52.5 48.5',
#  'person 61.0 71.5 chair 79.0 85.5 umbrella 5.5 58.0 bottle 55.0 88.0',
#  'person 46.0 34.0 fire_hydrant 68.0 33.5 person 18.5 37.0 person 19.5 12.5 person 8.0 8.5',
#  'tv 57.0 24.5 laptop 19.5 70.0 mouse 22.0 79.0 keyboard 52.0 73.0',
#  'cup 77.0 26.5 person 36.0 42.0 person 34.5 5.0 refrigerator 61.0 26.5 cup 58.0 53.5 cake 52.0 73.5',
#  'bottle 37.0 38.0 cup 60.0 60.0 bottle 89.5 35.0 cup 83.5 48.0 person 40.0 1.0 person 85.0 8.5',
#  'person 48.0 5.5 person 31.5 24.5 person 30.0 67.0 person 69.0 27.0 person 9.5 70.0 skateboard 26.0 39.0',
#  'giraffe 58.0 47.5 giraffe 34.0 52.0',
#  'cake 52.0 26.5 sandwich 7.0 54.0',
#  'clock 33.0 50.5',
#  'person 42.0 55.0 person 91.5 42.5 person 77.5 31.5 bicycle 78.5 41.5',
#  'person 23.0 55.5',
#  'person 63.5 52.5 person 30.5 51.5 person 18.0 51.0 person 26.5 53.0 person 49.5 52.0 person 66.0 20.0 person 95.5 21.0',
#  'bird 53.0 64.0',
#  'person 46.5 7.0 person 12.5 41.0 person 13.0 83.5 tennis_racket 45.5 61.5',
#  'person 29.0 6.5 person 73.0 13.5 tie 40.5 37.5',
#  'giraffe 46.5 66.5',
#  'chair 31.0 83.5 person 45.5 44.0 person 31.0 43.5 person 16.0 61.0 chair 34.0 85.5 chair 87.5 81.5 person 29.5 44.0 chair 14.0 76.5 person 89.5 47.5 person 85.5 61.5 person 70.0 61.0 cup 26.5 56.5 dining_table 45.0 65.5',
#  'train 50.0 54.5',
#  'cup 52.0 75.5 person 66.5 36.0 person 21.5 8.5 person 34.5 9.5',
#  'car 49.0 9.5 dog 62.5 39.5',
#  'motorcycle 10.0 64.5 person 54.5 39.5',
#  'tie 50.0 33.5 person 13.0 5.5',
#  'fire_hydrant 74.5 52.0',
#  'bowl 75.0 65.0 bowl 71.0 20.0 bowl 3.5 65.0 bowl 33.5 20.5 carrot 74.0 22.0',
#  'person 49.5 51.5 person 3.0 61.0 tennis_racket 55.5 9.0',
#  '',
#  'cow 39.5 50.5 cow 67.0 76.5 cow 26.0 63.0 cow 46.5 39.5 cow 45.0 49.5 cow 50.5 80.0 cow 16.0 38.0 cow 33.0 35.0 cow 52.5 51.0 cow 59.5 52.0 cow 66.5 37.0 cow 32.0 45.0 cow 56.5 41.0 cow 23.0 32.0 cow 29.5 40.5',
#  'bicycle 29.5 70.5',
#  'broccoli 64.5 51.0 broccoli 18.0 51.0',
#  'giraffe 42.5 51.0 giraffe 33.0 47.5',
#  'bus 42.5 33.0 person 70.5 58.0 person 24.0 26.0 person 36.5 23.5 car 33.5 49.0 person 66.5 56.0 car 61.0 24.5 chair 18.5 72.0',
#  'car 9.0 44.0 car 50.5 42.0 car 72.0 88.5 truck 22.5 85.0 car 34.5 86.5',
#  'motorcycle 52.5 44.5',
#  'person 65.5 65.0 person 45.5 28.5 person 24.5 65.5 person 44.5 46.5 person 15.0 47.5 person 86.0 62.0 frisbee 29.5 3.0',
#  'giraffe 45.5 51.5 giraffe 36.0 70.0',
#  'teddy_bear 27.5 55.5 teddy_bear 75.5 56.0',
#  'person 8.0 6.0 cup 51.5 49.0 person 82.0 19.0 person 45.5 19.5 person 17.0 54.0',
#  'car 12.5 51.0',
#  '',
#  'bench 23.5 59.0',
#  'suitcase 52.5 34.5 person 4.5 9.0 backpack 48.0 56.5 person 6.0 40.0 suitcase 46.5 81.5 person 15.5 28.5 person 74.0 50.5 handbag 6.5 36.0',
#  '',
#  'knife 26.5 2.0 cake 53.5 49.5 bowl 20.0 5.5 dining_table 6.5 49.0 fork 1.5 34.5',
#  'person 70.5 53.5 person 23.0 5.0 baseball_glove 51.0 44.5 person 46.5 27.0 person 51.0 46.0 person 43.0 26.5 person 51.0 58.5 person 13.5 17.5 person 86.5 58.5 baseball_bat 43.5 22.5',
#  'clock 15.0 35.5',
#  'person 75.5 54.0 sports_ball 30.0 25.5',
#  'truck 47.0 56.0',
#  'person 7.0 44.5 person 23.0 35.5 person 43.0 56.0 person 14.5 27.0 person 56.0 51.0 person 18.5 26.5',
#  'person 9.5 71.5 person 42.0 73.0 person 19.5 73.0 person 3.0 74.0',
#  'scissors 43.0 20.5 dining_table 5.0 5.0',
#  '',
#  'vase 88.0 45.0 chair 44.5 53.0 potted_plant 61.0 45.5 chair 9.0 55.0',
#  'stop_sign 42.5 26.0 car 57.0 35.0',
#  'person 43.0 49.5',
#  'tv 26.5 27.0 vase 61.0 44.0',
#  'person 6.0 55.5',
#  'keyboard 36.5 36.0 tv 60.5 51.5 mouse 66.5 67.5 keyboard 39.0 61.0 laptop 40.0 51.5',
#  'toilet 43.0 43.0',
#  'sheep 49.0 81.5',
#  'cat 41.5 51.5',
#  'clock 78.0 30.5 sports_ball 14.5 45.0',
#  'person 26.5 56.5 boat 55.0 25.5 person 65.0 50.0',
#  'sink 13.0 61.5',
#  'bus 1.0 70.0 bus 40.0 74.5',
#  'cake 50.0 44.0',
#  'cat 49.0 51.0',
#  'truck 25.0 55.0 car 43.0 46.0 truck 69.0 58.0 person 4.5 59.5',
#  'train 42.0 56.0 train 51.0 56.5',
#  'traffic_light 83.5 16.5',
#  'elephant 33.5 50.0',
#  'person 24.0 17.0 skateboard 35.0 27.5',
#  'person 93.0 36.0 person 58.5 35.5 person 48.5 28.5 person 1.5 65.5 person 79.0 38.5',
#  'person 32.5 22.0 person 77.0 21.0 person 15.5 29.5 bottle 54.5 15.0 pizza 49.0 74.5 cup 76.5 38.0 pizza 47.0 47.5 pizza 38.0 82.0 dining_table 49.5 51.0 cup 65.0 34.0',
#  'bowl 48.0 74.5 dining_table 33.0 9.5 bowl 31.5 89.0 bowl 48.0 87.0 clock 71.5 15.0',
#  'clock 47.5 48.0 person 48.0 89.0 clock 22.5 53.0 clock 9.5 42.5 clock 72.0 42.5 clock 29.5 28.5 person 73.0 45.5',
#  'chair 23.0 77.0',
#  'kite 16.0 1.5 kite 36.5 17.5 person 28.5 66.0',
#  'person 53.5 51.0 cup 82.0 76.5 cake 50.0 79.5 person 62.0 26.5 person 50.5 49.0',
#  'person 32.5 55.0 person 63.5 63.0',
#  '',
#  'giraffe 48.5 41.0 giraffe 31.5 51.5 giraffe 57.0 51.0',
#  'sink 31.0 53.0',
#  'cake 41.0 30.5',
#  'elephant 52.5 41.5',
#  'person 39.5 46.5 car 14.5 31.0 car 56.5 31.0 skateboard 41.0 74.5 car 13.0 15.0 car 46.5 31.5',
#  'carrot 78.0 29.0 broccoli 22.0 43.5 broccoli 47.5 29.5 bowl 7.5 48.5 carrot 53.0 50.0 carrot 22.5 30.5 broccoli 51.0 49.5',
#  'bowl 10.5 18.0 sandwich 64.5 19.5 cup 23.0 64.5 bottle 22.0 26.5 sandwich 43.0 74.0',
#  'fire_hydrant 49.5 47.5',
#  'bird 35.5 66.5',
#  'cup 48.5 72.5 person 49.5 56.5 cup 36.0 27.0',
#  'clock 51.5 26.5 person 17.5 73.5 person 45.5 38.5 person 9.0 38.0',
#  'person 48.5 56.0 person 18.0 66.0 person 4.0 68.5 person 17.0 65.0 person 58.5 49.5 person 81.0 67.5 person 41.5 52.0 person 25.0 25.5 dining_table 65.5 52.5',
#  'cat 45.0 62.0 toilet 37.0 83.5 sink 47.5 37.0',
#  'train 37.0 41.0',
#  'person 24.5 40.5 car 40.0 32.0',
#  'person 48.5 51.0',
#  'bus 53.0 50.0 bus 51.5 59.0 bus 88.0 57.5 person 14.0 34.0 person 20.0 34.5 person 17.5 36.0',
#  'person 46.0 46.0 person 34.0 42.0 dog 25.5 56.5 car 70.0 40.5',
#  'bowl 33.0 5.0 apple 64.5 43.5 bowl 32.0 55.5 person 44.0 23.0 apple 82.0 50.0',
#  'person 45.0 47.5 car 51.0 25.5 handbag 42.5 54.5',
#  'elephant 57.5 59.5 person 25.5 21.0',
#  'person 52.0 54.0 cake 36.0 79.0',
#  'pizza 5.0 49.5 orange 29.5 21.0',
#  'vase 42.0 71.0',
#  'zebra 30.5 39.0',
#  'person 29.5 70.5 kite 32.5 23.0 person 89.0 70.5 person 90.0 71.0',
#  'bed 14.5 20.5 cat 41.0 49.0',
#  'horse 29.5 40.5 person 32.5 50.0',
#  'train 55.0 65.0 clock 4.0 21.0',
#  'refrigerator 52.5 5.0',
#  'giraffe 66.5 45.5 zebra 35.0 63.5',
#  'pizza 49.5 69.0 pizza 80.0 19.5 car 87.0 8.5 bottle 8.5 37.0 person 54.0 21.5 car 75.5 1.0',
#  'zebra 31.5 31.5 sheep 6.5 57.0 sheep 7.5 55.0',
#  'keyboard 63.5 71.0 person 40.5 58.0 tv 27.0 55.0 cup 63.5 62.0',
#  '',
#  'person 47.5 77.0 person 41.5 74.0 boat 52.5 64.5 boat 2.5 74.5',
#  'boat 50.5 33.0',
#  'person 62.5 53.0 person 12.5 49.0 person 80.5 45.0 person 2.0 69.5 person 90.0 9.5 baseball_glove 13.5 63.0 baseball_bat 52.5 17.5 baseball_glove 13.5 62.0 person 35.0 7.0',
#  '',
#  'person 68.0 63.0 umbrella 63.0 24.0',
#  'airplane 31.0 44.0 airplane 50.0 38.5',
#  'car 6.5 83.5 car 78.0 80.5',
#  'vase 25.5 67.0',
#  'person 22.0 37.5 person 28.0 57.5 dog 48.5 63.5',
#  'clock 4.5 40.0',
#  'person 57.0 44.0 skis 51.0 83.5',
#  'person 26.0 37.0 person 93.5 59.0 person 9.0 58.0',
#  '',
#  'person 45.5 53.0 tennis_racket 35.5 55.0',
#  'person 35.0 54.5',
#  'person 22.5 30.5',
#  'person 22.0 13.0 person 70.0 13.0 pizza 45.0 49.5',
#  'person 24.5 78.5 person 90.0 15.0 person 11.0 48.0 person 49.0 12.5 person 32.0 77.0 person 44.5 48.0 skateboard 44.0 21.0 skateboard 54.5 90.5 person 66.5 8.0 skateboard 67.5 62.0 person 20.0 2.0 skateboard 8.5 46.0 person 70.5 50.5 person 8.5 75.0 person 92.5 76.0 person 83.0 48.5 skateboard 13.0 58.5 skateboard 26.5 59.0 person 59.5 7.0 skateboard 33.0 86.5 skateboard 91.5 29.5 skateboard 46.5 59.5',
#  'person 6.5 43.0 teddy_bear 82.0 66.0',
#  'person 9.5 24.0 person 7.5 21.5 person 66.5 7.5 person 7.5 23.0 person 41.0 25.0 person 50.0 25.5',
#  'bench 35.5 37.0',
#  'horse 68.0 21.5 person 87.0 41.0 person 34.0 56.0 person 13.5 25.5',
#  '',
#  'person 49.0 12.5',
#  'person 77.0 52.5 person 47.5 48.5 person 62.0 23.0 person 25.5 63.5',
#  'elephant 59.5 55.5 elephant 38.5 59.5 elephant 49.0 57.5 elephant 40.0 47.5',
#  'person 49.5 50.0',
#  'person 47.0 50.0 person 20.5 52.0 person 29.5 54.0 person 13.0 51.5 sports_ball 17.0 29.0 person 41.0 53.0',
#  'car 29.5 63.0 car 47.0 68.5 car 53.0 64.5 car 32.0 39.5 traffic_light 36.5 30.0 traffic_light 40.0 30.0 car 10.0 45.5 person 7.0 58.0 car 75.5 61.0',
#  'person 39.5 59.5 person 10.5 65.0 person 50.5 61.5 kite 25.0 18.0 kite 75.0 33.5 kite 55.0 34.5 person 37.0 60.0 person 40.5 60.5 person 53.0 59.0 person 22.0 60.0',
#  'person 78.5 51.5 person 50.0 73.0 kite 14.5 41.5 kite 21.0 2.0 person 28.0 71.5 kite 45.0 20.5 person 40.0 75.5 kite 3.5 31.0 kite 34.5 37.5 handbag 49.0 67.5',
#  'person 35.0 53.5 person 50.0 57.5 frisbee 24.0 7.5',
#  'cat 50.5 65.0',
#  'person 42.0 49.5',
#  'toilet 28.0 28.5 sink 47.5 25.5',
#  'zebra 27.5 80.5 giraffe 59.5 26.5',
#  'person 29.0 46.5 person 14.5 40.0 person 84.5 80.0 person 40.0 77.5 person 74.0 46.5 person 35.5 47.5 person 7.0 78.0',
#  'frisbee 28.5 38.0 person 59.5 49.5',
#  'fork 23.5 40.5 pizza 14.5 12.5 cup 35.0 14.0 fork 23.0 45.5 pizza 50.0 54.0 dining_table 5.0 5.5',
#  'person 51.0 51.0 person 29.5 64.0 bowl 48.0 6.5 person 53.5 51.5',
#  'person 45.0 6.0 tie 51.0 59.5',
#  'person 20.5 65.0 person 40.0 65.0 person 13.0 63.0 person 6.5 63.5 person 2.5 5.5',
#  '',
#  '',
#  'clock 49.0 42.5',
#  'laptop 39.5 54.5 wine_glass 68.0 64.0',
#  'surfboard 69.0 67.5 person 86.0 27.0',
#  'person 62.0 15.5 person 28.5 12.0',
#  '',
#  'tv 0.5 7.0 person 29.0 5.5 bottle 46.5 46.0',
#  'person 49.0 41.5',
#  'pizza 45.5 52.0',
#  'sheep 25.5 55.5',
#  'bus 38.5 47.5 car 47.0 47.0 car 52.5 43.0 car 2.0 57.0 traffic_light 30.5 2.0',
#  '',
#  'giraffe 44.5 61.5 giraffe 60.5 57.5',
#  '',
#  'bear 36.5 59.5 sheep 30.0 55.0',
#  'motorcycle 55.5 65.0 person 37.5 53.0',
#  'person 59.5 39.0 motorcycle 45.5 30.0 person 32.0 39.0 motorcycle 60.5 31.0',
#  'fire_hydrant 53.0 56.0',
#  'bowl 5.0 59.5 broccoli 18.0 42.0',
#  'person 6.5 6.5 cell_phone 79.0 33.0',
#  'person 67.0 26.5 person 24.5 70.5 tennis_racket 84.0 23.5',
#  'vase 64.0 62.0 tv 42.0 34.5 book 8.5 79.5 person 41.0 34.5',
#  'bird 55.5 57.0 bird 30.0 23.0 bird 42.5 57.5',
#  'cat 37.5 40.0',
#  'cow 46.0 52.0 cow 32.5 56.0 cow 87.0 54.0 bird 77.5 25.0 bird 26.0 18.0 bird 16.5 28.5 bird 95.0 37.0',
#  'traffic_light 56.0 52.5 traffic_light 43.0 49.0 traffic_light 33.0 51.5 traffic_light 44.5 61.0 traffic_light 75.0 58.5 car 18.5 84.5 traffic_light 58.0 30.5 traffic_light 70.0 30.0 traffic_light 47.0 50.0 traffic_light 12.0 47.0 car 24.5 85.0 car 50.5 84.0 traffic_light 4.5 47.0 truck 9.0 48.0 truck 75.0 48.0',
#  'bottle 33.5 22.0 cup 61.5 34.5 fork 11.5 71.0 dining_table 49.5 49.5 knife 89.0 70.5 bottle 34.5 17.0',
#  'laptop 25.5 67.5 person 50.0 58.0 book 71.5 63.0 bowl 20.0 6.0 book 73.0 68.5',
#  'traffic_light 90.5 25.5',
#  'tv 29.5 49.5 tv 67.5 77.0',
#  'elephant 46.5 51.5',
#  'elephant 47.0 40.5',
#  'elephant 46.5 39.5 car 11.0 66.0',
#  'person 26.5 63.0 horse 65.0 57.0 person 32.5 35.5',
#  'tie 85.5 67.0 person 11.5 51.0 person 22.0 6.0 person 1.5 14.5',
#  'dining_table 5.0 52.0 wine_glass 84.0 76.5 person 48.0 46.5 person 25.5 25.0 person 6.0 26.5 person 46.0 59.5 person 48.0 25.0 person 51.0 49.0 cup 78.0 82.0 person 15.0 53.0',
#  'person 5.5 5.0 tie 46.5 60.5',
#  '',
#  'elephant 59.5 78.0 elephant 14.5 48.5',
#  'bed 5.0 5.0 book 14.0 74.5 person 15.0 5.5 person 6.0 5.0',
#  'vase 38.5 63.0',
#  'clock 32.5 27.5',
#  'bicycle 40.0 49.5 person 32.0 52.5 person 42.0 46.0 person 79.5 52.0',
#  'cat 49.5 33.5 keyboard 48.5 44.0',
#  'airplane 51.0 47.5',
#  'teddy_bear 59.5 47.0 orange 27.0 79.0 person 52.5 14.5',
#  'toilet 77.0 33.5 sink 56.0 47.5 bottle 70.0 24.0',
#  'bird 35.0 49.5',
#  'clock 60.0 20.5 fire_hydrant 30.0 58.0',
#  'fire_hydrant 51.0 73.0 person 11.5 27.5 person 87.5 50.0 suitcase 8.0 75.5',
#  'vase 24.0 68.0 vase 68.0 70.0',
#  'chair 9.0 70.0 refrigerator 21.0 17.0 refrigerator 32.5 59.5',
#  'bench 22.0 60.5',
#  'person 53.0 14.5 person 19.5 51.0 person 52.0 41.0 person 48.0 35.5',
#  'person 43.5 58.5',
#  'person 18.0 22.5 cat 66.0 72.0 tv 24.5 3.5 person 28.5 26.0',
#  'potted_plant 6.0 90.0 person 41.0 84.0 person 95.5 84.0 person 47.0 82.5 person 60.5 81.5 person 48.0 83.5 person 76.5 80.5 person 84.5 42.5 person 51.0 82.0',
#  'person 65.5 23.5 skateboard 56.5 53.0',
#  'chair 53.0 68.5 chair 93.0 69.5 chair 79.0 77.5 vase 45.5 17.5 vase 16.0 16.5 vase 2.0 25.0',
#  'bicycle 69.0 79.5 car 93.0 66.0 person 69.0 44.0 bicycle 32.5 82.0 car 49.0 76.5 person 32.5 72.5 traffic_light 34.0 48.0 traffic_light 39.0 50.5',
#  'person 28.0 8.5 couch 73.0 71.5 tie 21.5 71.0',
#  '',
#  'person 52.5 49.5 bed 37.5 65.0',
#  'dog 60.0 62.0',
#  'bear 44.5 51.0 car 1.5 11.5',
#  'giraffe 44.0 50.0',
#  'sports_ball 56.0 10.0 person 48.0 8.0 tennis_racket 14.5 83.0',
#  '',
#  'dining_table 50.5 7.0',
#  'person 29.5 51.5 person 48.5 50.0 surfboard 71.5 48.0 surfboard 18.5 44.5',
#  'bowl 37.5 47.5 bottle 69.5 30.5 bottle 36.0 9.5 cup 68.0 71.0 dining_table 5.0 57.0 bottle 55.5 24.0 cup 13.0 65.0 cup 77.0 32.0 sandwich 31.5 78.0 chair 21.5 12.0 fork 91.5 59.5',
#  'elephant 53.5 26.0',
#  'toilet 37.5 38.0 cat 26.5 13.5',
#  'person 36.5 50.0',
#  'fire_hydrant 67.5 7.0',
#  'zebra 22.0 54.5 zebra 32.5 58.0',
#  'bottle 51.0 63.0 wine_glass 40.5 75.0 wine_glass 41.0 63.5 person 85.0 48.5 person 15.0 35.5 person 70.0 41.0 bottle 15.0 49.5 person 47.5 42.5 bottle 36.0 41.0 person 33.5 29.5 person 37.0 26.0 person 24.5 18.0 person 44.5 55.5 dining_table 60.5 71.5 bottle 32.5 25.5 person 25.0 42.0',
#  'bus 13.0 51.0 bus 42.0 51.5 bus 52.5 52.5',
#  'person 32.0 34.0 skateboard 30.0 69.5 person 81.5 37.5 person 72.5 51.0 person 3.5 51.0 person 60.0 50.0 car 51.5 25.0 person 64.0 50.5 car 88.0 24.0 person 37.5 47.5 backpack 73.5 28.0 person 23.0 47.0 person 31.0 52.5 car 50.0 51.0',
#  'boat 84.5 33.5 person 14.0 59.5 boat 60.5 36.5',
#  'couch 33.5 31.0',
#  'person 73.5 21.5 person 7.0 63.0',
#  'car 39.0 61.5 horse 55.5 49.0 horse 63.0 33.0',
#  'person 56.5 13.5 tennis_racket 69.0 69.0 sports_ball 52.0 56.0',
#  'chair 49.0 80.0',
#  'bus 42.5 39.5 car 4.5 46.5 truck 42.5 42.0',
#  '',
#  'car 5.5 32.5 car 42.0 48.0',
#  'pizza 51.0 50.5 oven 46.5 5.0',
#  'horse 39.5 37.0',
#  'wine_glass 87.0 29.0 cup 35.5 19.0 pizza 49.0 65.0 knife 61.5 6.5 dining_table 50.5 8.5',
#  'mouse 56.0 57.5 laptop 44.5 6.5 tv 63.5 25.0 chair 20.0 50.0 tv 51.0 16.0 keyboard 30.0 30.5 chair 19.5 69.0',
#  'person 63.5 37.0',
#  'person 57.5 61.5 car 2.0 49.0 truck 19.0 4.5',
#  'person 37.0 25.0',
#  'stop_sign 32.0 61.5',
#  'person 47.5 12.0 tie 25.5 50.5 chair 12.0 8.0',
#  'surfboard 44.5 49.5 person 40.5 40.5',
#  'person 42.0 51.5 person 65.5 54.0 person 21.0 5.5 person 73.0 22.0 person 24.5 38.0 person 37.5 30.5 person 38.5 53.5',
#  'zebra 46.0 7.5',
#  'bottle 13.5 18.0 bottle 6.5 3.0 dining_table 5.0 8.0 pizza 34.5 51.0 pizza 40.5 37.5 pizza 51.5 18.5 cup 17.0 16.5 bottle 19.5 12.5',
#  'person 22.5 12.0 chair 5.5 76.0',
#  'bear 58.5 54.5',
#  'clock 24.5 51.5',
#  'clock 47.0 23.5 person 89.5 77.0 person 71.0 9.5 person 5.0 89.5 person 23.0 89.5',
#  'bottle 72.5 40.0',
#  '',
#  'chair 39.0 75.5 chair 59.0 62.5 person 45.0 46.0 chair 87.5 66.0 chair 63.5 43.0 chair 50.5 69.5 person 50.5 45.5 laptop 8.0 49.0 refrigerator 81.0 49.5',
#  'fork 9.0 75.5 pizza 6.0 35.5 fork 39.5 14.0 dining_table 5.5 49.5 fork 51.5 37.0 fork 44.5 7.0 pizza 38.0 41.0 cup 9.5 16.5',
#  '',
#  'tv 34.5 42.5 sink 44.0 45.5',
#  'person 14.0 65.5 person 33.0 64.5 elephant 52.0 42.0 elephant 90.5 50.0 elephant 51.0 41.0 elephant 58.5 49.0 elephant 86.0 38.0 elephant 15.5 34.0 elephant 39.5 54.0 elephant 66.0 62.0 elephant 39.0 23.5',
#  'person 53.0 60.0',
#  'truck 48.5 51.0',
#  'teddy_bear 19.5 48.5 teddy_bear 13.5 50.5',
#  'fork 18.0 61.5 pizza 5.0 47.0 pizza 1.5 6.0',
#  '',
#  'person 30.0 86.5',
#  'person 23.0 14.5 person 30.0 21.0 person 11.0 62.5 person 23.5 18.0 person 52.5 46.0',
#  'bicycle 54.0 49.5 car 30.0 24.0 car 68.5 12.0 car 44.5 21.0 car 59.5 25.5',
#  'person 9.0 6.5 toothbrush 69.5 61.5',
#  'oven 51.0 41.0 cup 39.5 15.0',
#  'toilet 44.0 72.5',
#  'car 50.5 35.5 clock 50.0 22.0 car 74.0 56.5 car 42.5 54.0 car 85.5 56.0 car 34.0 28.5 car 34.0 30.0 traffic_light 3.5 18.5 car 59.0 53.5 car 19.5 53.5',
#  'teddy_bear 51.0 46.5',
#  'bowl 59.5 39.5 bowl 17.5 45.5',
#  'bus 63.0 39.0 person 7.0 27.5',
#  'airplane 71.5 25.5 airplane 43.5 7.5',
#  'vase 46.5 79.5',
#  'car 49.5 55.5 car 69.5 54.0 car 82.0 27.5 car 34.5 55.5 car 51.5 54.5 car 89.0 31.5',
#  '',
#  'sheep 53.0 49.0 car 1.5 46.5',
#  'zebra 36.0 5.0 zebra 50.0 49.5',
#  '',
#  'toilet 36.5 59.5 cat 70.0 36.0',
#  'person 42.0 33.5 person 12.0 41.5 skateboard 65.5 46.0',
#  'bird 60.0 65.0',
#  'person 39.0 37.5 person 38.0 37.5 person 52.5 21.0 person 24.0 32.0',
#  'person 61.5 43.0 person 32.0 37.5 person 56.5 78.5',
#  'laptop 23.5 61.5 cat 63.0 61.0 person 18.0 50.0',
#  'person 63.0 54.0 person 16.5 49.5 person 34.5 61.5 backpack 51.5 50.0 person 20.5 64.5',
#  'dining_table 52.5 58.5',
#  'pizza 11.5 55.5 cup 49.0 52.0 dining_table 7.5 62.0',
#  'surfboard 57.0 58.0 person 28.5 49.5',
#  'train 46.0 44.0',
#  'person 31.5 17.0 person 74.0 51.5 bowl 41.5 48.5 bowl 25.0 44.0 chair 24.5 34.0 chair 88.5 72.5',
#  'person 58.0 35.5',
#  'carrot 51.0 77.0',
#  'person 36.5 62.5 person 29.5 55.0 person 7.5 53.5 car 39.0 50.5 umbrella 26.5 45.0 umbrella 46.0 42.5',
#  'bus 46.0 50.0',
#  'motorcycle 32.5 60.5 person 78.0 44.0 person 65.5 4.5 person 59.5 51.5 car 91.0 38.5 person 38.5 46.0 car 79.0 18.5 car 52.5 41.5 person 20.0 39.0 truck 45.5 22.0',
#  'oven 49.0 63.0',
#  'bottle 26.5 66.0',
#  'laptop 50.5 56.0 cup 78.5 49.0 book 9.0 83.0',
#  'elephant 73.5 51.5',
#  'boat 43.5 52.0',
#  '',
#  'person 24.5 32.5 chair 8.5 61.5 dining_table 5.0 26.0 cup 48.0 81.0 couch 42.0 25.5 cup 48.5 72.5 chair 29.0 51.0 bowl 36.5 62.0',
#  'traffic_light 53.0 32.5 person 29.5 64.0',
#  'person 4.5 5.0 cell_phone 28.0 47.0',
#  'person 22.0 51.5 pizza 34.0 48.5',
#  'person 94.0 23.5 person 86.0 23.0 suitcase 12.0 5.5 suitcase 58.5 46.5 suitcase 35.5 23.5',
#  'pizza 4.0 52.5 dining_table 49.5 48.0',
#  'bus 56.5 48.5 car 39.5 41.0 potted_plant 84.5 61.0 bus 76.5 41.0',
#  'tennis_racket 7.0 49.0 sports_ball 66.5 49.5',
#  'cat 6.0 46.0',
#  'person 50.0 63.0 sports_ball 38.5 55.0 person 37.0 39.5 person 28.5 31.0 person 41.0 31.0 person 10.0 20.0 person 48.0 31.5 person 20.5 28.0',
#  'kite 50.5 59.0 person 3.0 86.0 kite 17.0 73.5 kite 23.0 73.5 kite 9.5 71.0',
#  'person 8.0 51.0 person 85.5 9.0 tennis_racket 67.5 26.5 person 44.0 51.0 person 25.5 46.0 person 41.5 8.5 person 54.0 9.5',
#  'clock 40.0 43.0',
#  'motorcycle 54.0 43.0',
#  'person 1.0 69.0 hot_dog 29.5 45.5 person 42.5 24.0 person 64.5 36.0 hot_dog 55.5 66.5 person 44.5 6.5 person 74.5 47.0 chair 10.5 14.0',
#  'person 25.5 41.0 giraffe 55.5 70.5 horse 34.0 39.5 horse 22.5 59.0 giraffe 45.0 28.0',
#  'person 24.0 25.5 cake 39.5 53.5 dining_table 49.0 26.0 chair 31.0 35.5 person 8.5 40.5 chair 86.0 59.0 person 44.0 35.5',
#  'person 38.5 47.5 skateboard 36.0 84.5',
#  'train 9.0 47.5',
#  'person 34.5 34.0 suitcase 27.5 62.0',
#  'tv 56.0 34.0 clock 2.5 37.5 person 57.0 20.0',
#  'person 32.5 58.5 umbrella 26.5 29.0 person 48.0 42.0 dining_table 21.5 89.0',
#  'person 66.5 56.5 person 28.5 50.5',
#  'person 3.5 40.5 wine_glass 18.0 42.0 wine_glass 68.0 69.0 bottle 51.5 53.5 bottle 59.0 29.5 bottle 63.5 30.0 dining_table 5.0 37.0',
#  'toilet 49.0 36.5',
#  'cell_phone 62.0 45.5 person 5.0 48.0',
#  'cell_phone 71.0 60.0 remote 68.5 80.0',
#  'person 40.5 56.0 umbrella 17.0 24.5 bench 17.5 56.5',
#  'boat 49.0 61.5 person 68.0 48.5 person 53.0 47.5 person 62.5 44.0',
#  'laptop 22.0 49.5 person 46.5 86.5',
#  'pizza 34.5 54.0 person 31.5 47.5 person 33.0 8.0',
#  'person 25.5 49.5 motorcycle 36.0 44.5 person 77.0 27.5 car 9.5 27.5 person 10.5 35.5 motorcycle 72.5 47.5 bus 15.5 19.5 motorcycle 29.0 55.0 person 25.0 41.0 person 53.5 13.0 person 46.5 50.5 person 24.5 34.0',
#  'sheep 59.5 79.0 sheep 52.5 37.0 person 46.5 51.5 sheep 71.5 51.0 person 10.0 47.5 sheep 88.5 82.0 sheep 80.0 83.5',
#  'chair 27.5 78.0 chair 9.0 81.0 potted_plant 47.0 21.5 couch 27.0 78.0 couch 72.5 73.5',
#  'wine_glass 27.0 25.5 dining_table 5.0 5.0 cup 40.5 28.0 spoon 64.0 19.5',
#  'zebra 8.0 6.5',
#  'person 38.5 56.5 car 26.5 25.5 bench 50.0 65.5 potted_plant 10.5 23.0 potted_plant 29.5 18.0',
#  'cat 49.0 57.0',
#  'person 35.0 53.5',
#  '',
#  'person 35.5 58.5 person 16.5 78.5',
#  'person 64.0 55.5 person 30.0 52.5',
#  'couch 30.5 58.5',
#  'laptop 17.0 41.5 suitcase 30.5 55.5',
#  'spoon 68.5 62.5 cup 45.5 18.0 cake 47.0 55.0 dining_table 49.5 14.5 bowl 47.0 47.0',
#  'person 19.5 84.5 bird 71.0 70.5',
#  'bowl 76.5 48.5 person 36.0 40.5 person 42.5 33.5 bowl 55.5 87.0',
#  'person 37.5 48.5',
#  'person 42.5 44.5 person 84.5 13.0 person 1.0 30.0 person 9.0 16.0',
#  'book 22.5 24.0 book 51.5 25.0',
#  '',
#  'person 33.0 50.0 surfboard 31.0 56.0',
#  'traffic_light 53.0 35.0 traffic_light 65.5 19.5 traffic_light 73.0 15.0 truck 43.5 64.0 traffic_light 70.0 24.5 traffic_light 54.5 24.5 traffic_light 43.0 45.0',
#  'person 41.0 55.0 person 43.0 32.0 person 51.5 43.5 tennis_racket 24.5 11.5',
#  'elephant 13.0 71.5 person 54.0 45.5 person 36.0 38.5 person 46.0 36.5',
#  'airplane 49.0 49.0',
#  'person 44.5 72.5 person 11.0 74.0 person 40.0 70.5 elephant 46.5 46.5',
#  'person 69.0 51.5 horse 45.5 62.5',
#  'person 41.0 22.0 person 36.0 16.0 car 5.5 39.5 car 88.5 42.5 car 77.5 40.5 traffic_light 51.0 12.5 person 35.5 40.0 person 62.5 39.5 traffic_light 46.5 12.5 person 11.5 45.0 person 59.5 39.5',
#  'person 33.0 54.5 person 70.5 51.5 tie 69.5 69.0 tie 28.5 29.0',
#  'person 1.0 68.5 person 43.5 65.5 person 78.0 44.0 cup 66.0 78.0 cup 41.5 49.0 person 77.0 62.5 wine_glass 24.0 87.5 dining_table 54.0 70.5 wine_glass 63.5 69.5 person 65.5 30.5 person 66.0 45.5 person 51.5 23.5 person 33.0 42.5 bowl 57.0 46.0 cup 40.0 80.5 cup 46.0 53.0 person 7.5 66.0 person 39.5 4.0 person 29.0 45.0 person 38.0 11.0',
#  'sandwich 42.5 59.0 donut 35.0 67.5 bowl 35.0 34.0',
#  'train 34.0 47.5',
#  'person 17.0 74.0 person 9.0 30.5 person 56.5 61.5 person 31.0 63.5 person 70.0 65.0 person 8.0 9.0 person 66.5 66.0 truck 21.5 55.0 car 48.5 59.0 person 2.5 30.0 car 23.0 57.0',
#  'truck 43.5 53.5',
#  'cup 24.0 23.0 cup 52.5 37.5 cup 1.0 33.5 sandwich 16.0 7.0',
#  'train 49.5 53.0',
#  'person 6.0 47.5 person 70.0 39.5 person 30.5 58.5 person 52.0 36.5 person 25.0 29.5 car 76.5 30.0',
#  '',
#  'vase 40.5 43.0 bowl 32.5 35.5 orange 55.5 62.0',
#  'person 15.0 36.5 person 56.5 32.5 person 47.5 56.5 person 47.5 10.5 person 56.0 57.5 person 29.5 26.0 baseball_glove 26.0 31.0 person 22.5 18.0',
#  'person 28.0 61.0',
#  '',
#  'person 45.0 48.5',
#  'dog 24.5 75.0 person 42.0 53.5 frisbee 36.0 8.5 sports_ball 36.0 8.5',
#  'person 45.0 72.0',
#  'zebra 12.5 49.0 zebra 82.5 51.0 zebra 32.0 50.0 zebra 53.0 54.5 zebra 69.5 56.0',
#  'person 78.5 55.0 train 67.5 36.5 bicycle 70.0 64.0 person 50.5 46.0',
#  'horse 86.5 22.0 person 34.5 40.5 horse 55.5 60.5',
#  'orange 19.0 49.5 orange 37.5 19.0 orange 31.0 26.5 orange 16.0 28.0',
#  'dining_table 5.0 5.0 cup 47.0 14.0 orange 90.5 38.5',
#  'banana 27.5 43.0',
#  'person 28.5 51.5 person 74.0 47.0 person 3.5 22.0 person 38.5 11.5',
#  'person 48.0 37.5 person 42.5 17.0 person 31.0 19.0',
#  'person 25.0 13.0',
#  'tv 25.0 33.5 mouse 66.0 88.5 keyboard 38.5 71.0',
#  'cat 49.0 56.0',
#  'kite 9.5 24.5 kite 24.0 40.5 kite 41.5 60.0 kite 19.0 51.5 kite 42.0 21.5 kite 28.5 11.5 kite 44.0 15.5',
#  'bear 36.0 15.5 bird 82.5 72.5',
#  'person 57.0 61.5 person 47.0 19.5 person 80.5 12.0 person 28.0 19.5 person 37.0 13.0',
#  'train 5.0 48.0 person 11.0 69.0',
#  'cup 19.0 67.0 dining_table 6.0 33.0 tv 17.5 40.0',
#  'giraffe 39.5 65.5',
#  'person 31.0 36.0 person 53.5 36.0 boat 57.0 38.5 person 49.0 36.5 person 45.0 36.5',
#  'orange 51.0 63.5 orange 77.0 70.0',
#  'bird 64.5 47.5',
#  'refrigerator 19.0 39.5 chair 31.0 28.0 dining_table 57.5 28.5',
#  'person 63.5 49.0 person 48.5 29.5 sports_ball 73.5 51.0',
#  'bus 32.0 53.0 person 60.0 60.0 bus 48.0 49.5 person 64.0 60.0 person 76.0 56.5 person 72.0 58.0 person 73.0 35.5 person 67.5 59.5',
#  'cat 32.0 28.0 person 6.5 26.0 cat 62.0 29.0',
#  'toilet 72.0 32.0 person 33.0 23.5',
#  'dog 47.0 47.0 tv 7.5 47.0 potted_plant 4.0 50.0',
#  'refrigerator 46.5 60.0',
#  'person 28.5 48.0 surfboard 51.5 64.0',
#  'motorcycle 68.0 50.0',
#  'toilet 14.5 40.5 toilet 24.0 47.0 sink 22.0 82.0',
#  'person 38.5 39.0 skateboard 19.5 34.5',
#  'person 21.0 49.5 tie 51.0 6.0',
#  'person 13.5 58.0 person 24.0 56.0',
#  'airplane 41.5 41.5',
#  'person 56.0 35.0',
#  'person 25.0 58.0 person 49.5 52.5 person 69.0 58.5 person 26.0 47.5 person 31.5 39.0 person 51.0 61.0',
#  'cat 51.5 9.0',
#  'person 61.0 15.5 truck 48.0 16.0 person 50.5 15.5 bus 3.5 51.5',
#  'truck 38.0 49.5',
#  'person 43.5 68.0 person 65.0 49.5 person 59.5 53.0',
#  'person 42.5 15.5',
#  'boat 50.0 10.0',
#  'sandwich 5.0 49.5',
#  'orange 38.0 50.5 banana 24.0 20.5 apple 83.0 15.0',
#  'bench 39.0 59.0',
#  'fire_hydrant 64.0 67.5',
#  'chair 25.0 85.5',
#  'teddy_bear 4.0 52.0',
#  'knife 19.0 25.5 cake 66.5 39.0',
#  'person 21.5 50.0 person 58.0 49.0 person 39.0 37.5 bottle 11.5 44.5 person 77.5 35.5 person 45.5 25.5 bottle 28.0 81.0 person 45.5 42.5 cup 79.0 59.0 bottle 35.0 46.0 chair 43.0 27.5 cup 50.5 82.5 cup 40.0 36.5 chair 38.0 55.0 cup 85.5 68.0 cup 83.5 68.0',
#  'car 29.0 83.0',
#  'pizza 32.0 60.5 cup 87.5 30.5 pizza 58.0 46.5 knife 45.5 82.5 person 62.5 25.5',
#  'person 35.0 47.5 person 17.0 36.0 person 7.5 23.5',
#  'cat 35.5 54.5 cat 70.0 61.5',
#  'chair 78.0 65.5 keyboard 27.5 46.0 keyboard 44.0 24.0 cup 34.0 46.5 mouse 1.5 83.0 tv 81.5 1.5 tv 3.5 22.5 tv 36.5 22.0 tv 15.5 22.0',
#  'airplane 49.5 25.0',
#  'person 21.5 34.5 surfboard 48.5 35.0',
#  'dog 62.0 53.5 boat 40.5 61.5 person 34.0 52.5',
#  'laptop 66.0 36.5 chair 47.5 39.5 keyboard 52.5 19.5',
#  'person 50.5 43.0',
#  'bird 50.0 50.5',
#  'remote 11.5 61.5 bed 6.0 6.5 person 50.5 57.0',
#  'bed 10.5 31.5 chair 57.0 26.5',
#  'person 48.5 55.0 airplane 17.5 41.5 person 37.5 45.5 person 50.5 48.0 person 86.0 49.5 person 46.0 23.0 person 34.5 47.0 person 72.0 45.0',
#  'person 44.0 30.5 bench 48.5 76.5 person 31.0 68.5 bench 16.0 60.5 person 38.5 59.5 person 30.0 58.5 suitcase 38.5 75.0',
#  'motorcycle 48.0 54.5 person 34.0 23.5',
#  'person 62.5 28.5 skateboard 30.5 44.5 bench 28.5 60.0',
#  '',
#  'person 4.0 62.5 person 48.5 8.0 person 86.5 62.0 person 90.0 62.0 person 45.5 61.5',
#  'clock 36.0 47.5 truck 41.0 88.5 car 28.5 48.0 car 79.5 91.0',
#  'motorcycle 18.0 34.0 motorcycle 12.0 73.5 motorcycle 39.5 72.0 motorcycle 8.5 77.0 person 9.0 59.5 motorcycle 59.0 44.0 motorcycle 57.0 70.5 motorcycle 78.5 68.0 motorcycle 39.5 33.0 person 88.5 57.0',
#  'horse 55.5 54.0 person 53.5 25.5',
#  'stop_sign 49.0 45.5',
#  'broccoli 40.5 46.5 cup 24.0 6.5 dining_table 5.0 45.5 fork 66.5 17.0 knife 51.5 48.5',
#  'horse 24.5 41.5 horse 58.5 36.0 person 59.5 52.5',
#  'person 66.0 48.5',
#  '',
#  'umbrella 76.5 77.0 umbrella 68.5 53.5 umbrella 36.5 35.0 umbrella 22.5 64.5 person 39.0 75.0 umbrella 49.0 16.5 umbrella 68.0 7.0 person 4.0 71.0 umbrella 27.5 24.5 person 26.5 44.5 umbrella 63.0 46.0 umbrella 30.0 16.5 person 49.0 41.5 person 29.5 25.5 umbrella 39.0 11.0 person 67.5 72.5 umbrella 53.5 20.0 person 81.5 20.5 person 77.0 28.0',
#  'sink 53.0 9.0',
#  'pizza 44.5 73.5 oven 44.0 51.5',
#  'broccoli 10.5 61.5 person 61.5 8.5',
#  'person 76.0 30.5 car 36.5 74.0',
#  'person 32.5 56.0 person 10.5 31.0 baseball_glove 19.5 66.0 sports_ball 81.5 50.5 person 5.0 38.5 person 89.0 36.0 person 93.5 35.0',
#  'person 62.5 53.0 person 2.5 71.5',
#  'stop_sign 14.5 51.5 car 36.0 51.5 car 0.5 51.5 truck 64.5 48.0',
#  'orange 66.5 75.0 bowl 45.5 66.0 orange 21.0 45.0',
#  'dining_table 7.5 49.0 cup 56.0 62.5 donut 64.5 26.5 cup 34.0 46.5 spoon 56.5 41.5',
#  'person 44.5 32.0 skateboard 31.0 29.0',
#  'sheep 6.0 70.5 cow 59.0 54.5 person 69.5 34.5',
#  'person 72.0 70.0 person 39.0 48.0 person 33.0 13.5 person 31.0 7.0',
#  'person 9.0 73.0 person 55.0 62.5 kite 32.5 18.0 person 34.0 63.5 kite 96.5 15.5 person 86.5 58.0 person 50.5 63.5 person 60.5 58.0 kite 45.5 11.0 kite 27.0 3.0 person 51.0 60.0 person 68.0 30.0',
#  'person 50.0 10.5 toothbrush 36.0 47.5',
#  'snowboard 41.5 76.0 person 48.5 47.5',
#  'bed 46.5 72.5',
#  'person 76.5 44.0 person 69.5 46.5 surfboard 79.0 59.5',
#  'fire_hydrant 41.0 48.5 person 86.0 32.5 car 72.0 33.5 car 95.5 35.5',
#  'person 60.5 52.5',
#  'stop_sign 64.0 31.0',
#  'banana 25.0 26.0',
#  'person 69.0 5.0',
#  '',
#  'person 20.5 48.5 tennis_racket 19.0 65.0 sports_ball 29.0 31.5 chair 42.0 19.0',
#  'person 45.0 49.5 skateboard 57.0 39.5',
#  'bear 54.5 39.0',
#  'cell_phone 63.0 51.5 person 44.0 54.0 person 70.0 62.0',
#  'bottle 73.0 27.0 pizza 61.5 73.5 cup 51.5 41.5 dining_table 5.0 17.0 cell_phone 9.5 27.0 bottle 14.5 6.5',
#  'pizza 25.0 37.0',
#  'tv 48.5 26.0 chair 17.0 73.5 bench 17.0 73.5',
#  'person 33.0 48.0 motorcycle 9.0 76.5 person 74.5 37.5 person 50.0 49.0 motorcycle 38.5 73.0 bottle 58.0 20.5 person 51.5 37.5 bottle 56.5 20.5 person 41.0 40.0 bottle 60.0 20.0 person 8.5 48.0 person 46.5 50.0',
#  'bowl 4.5 57.0 bowl 74.0 31.5 bowl 71.0 37.5 cup 21.5 22.5',
#  'bench 70.0 68.0',
#  'bottle 53.0 61.0',
#  'tv 45.0 38.5 couch 28.5 55.5',
#  'person 76.5 49.0 tv 15.0 49.5 clock 81.0 8.5 bowl 30.0 51.5',
#  'keyboard 28.5 74.0 laptop 46.0 61.0 tv 61.0 43.5 tv 22.0 47.0 mouse 24.5 69.0 chair 14.0 49.5',
#  'carrot 14.0 41.0 carrot 20.5 14.0',
#  'person 85.0 72.5 person 51.5 51.5 baseball_glove 42.0 54.0 person 8.5 27.0 person 90.0 14.0 baseball_bat 32.5 38.5',
#  'airplane 49.5 50.5',
#  'kite 46.5 70.0 skis 24.5 61.5 person 51.5 81.5 person 27.0 48.5',
#  'stop_sign 42.0 67.0',
#  'truck 51.0 60.0 car 3.0 30.5 car 93.0 50.0',
#  'bus 5.0 52.5 bicycle 10.5 44.0',
#  'sandwich 52.0 49.0',
#  'pizza 42.0 40.5 pizza 19.0 41.0',
#  'person 7.0 40.0 person 41.0 56.0 person 78.5 27.5 person 47.0 36.0 skis 8.5 71.5 person 51.0 36.0',
#  'vase 51.0 55.5',
#  'cat 51.5 58.5',
#  'person 62.0 15.5 baseball_glove 33.5 66.5',
#  'sink 35.5 71.5 bottle 20.0 29.0',
#  'person 73.5 7.0 person 47.0 5.0',
#  'bird 19.5 27.0 person 49.5 39.0',
#  'person 44.5 40.5 car 26.5 15.0 potted_plant 10.0 18.0 kite 37.0 79.0',
#  'train 2.0 34.5 person 40.5 6.5',
#  'tv 10.5 44.5 keyboard 21.0 41.5 laptop 78.5 57.5 tv 9.0 49.0 cat 55.0 62.5',
#  'truck 49.0 69.0 car 15.0 69.0 car 8.5 32.0',
#  '',
#  'person 58.0 76.5 traffic_light 67.5 36.5',
#  'sheep 60.0 46.0 sheep 29.0 63.0 sheep 7.5 26.5',
#  'skateboard 54.0 86.5 person 51.5 50.0',
#  'horse 38.5 61.5 person 68.0 50.0 person 25.5 48.0 person 11.0 30.5 person 92.0 32.5 person 30.0 24.0 person 86.5 5.0',
#  'person 49.0 8.0 tie 47.5 34.0',
#  'bed 68.5 72.5 chair 26.5 79.0 dining_table 12.0 79.0',
#  'person 74.5 7.5 tennis_racket 19.0 24.5',
#  ...]

# %%
output_list[1:4]
# Out:
# ['frisbee 48.0 34.0 person 17.0 7.5 person 34.5 13.0 person 69.0 5.0 person 87.0 27.5 frisbee 71.0 19.0 frisbee 16.5 56.0',
#  'car 30.5 52.0 train 79.5 39.0',
#  'stop_sign 53.0 35.0 car 35.5 87.5']

# %%
def get_location(coord):
    x = coord[1]
    y = coord[2]
    location_x = ""
    location_y = ""
    if x >= 0 and x < 33:
        location_x = "left"
    elif x >= 33 and x < 66:
        location_x = "middle"
    elif x >= 66 and x <= 100:
        location_x = "right"
    if y >= 0 and y < 33:
        location_y = "top"
    elif y >= 33 and y < 66:
        location_y = "middle"
    elif y >= 66 and y <= 100:
        location_y = "down"
    return location_y + " " + location_x

lst = output_list
final_output=[]
for coord_str in lst:
    coords = coord_str.split()

    obj_coords = []
    for i in range(0, len(coords), 3):
        obj_coords.append([coords[i], float(coords[i+1]), float(coords[i+2])])
    # print(obj_coords)
    locations = []

    for coord in obj_coords:
        x=get_location(coord)
        if(x=='middle middle'):
            x='center'
        locations.append(coord[0] + " location " + x)

    output_str = " ".join(locations)
    final_output.append(output_str)
final_output
# Out:
# ['person location top right person location top left person location middle left person location top middle person location center person location center person location center person location middle right person location top left person location down middle',
#  'frisbee location center person location top left person location top middle person location top right person location top right frisbee location top right frisbee location middle left',
#  'car location middle left train location middle right',
#  'stop_sign location center car location down middle',
#  'person location top right person location center',
#  'bird location center',
#  'horse location center person location top left person location middle right',
#  'pizza location middle left',
#  'person location middle left person location center person location middle left person location top left cell_phone location center',
#  'person location down middle person location down left person location middle left person location middle left person location center person location down right person location middle left person location down right',
#  'bed location center chair location middle right dining_table location down middle',
#  '',
#  'person location center baseball_bat location top middle',
#  'couch location top left cat location top left',
#  'cat location top right bicycle location middle left',
#  'giraffe location middle right giraffe location middle left giraffe location middle left giraffe location middle left',
#  'airplane location center',
#  'car location down middle clock location top right',
#  'motorcycle location center person location center',
#  'motorcycle location top middle person location middle right',
#  'motorcycle location center person location middle left person location middle left person location center person location center person location middle left person location center person location center person location top middle',
#  'toilet location down left',
#  'cup location middle right',
#  'car location middle right person location middle left car location center',
#  'person location center cake location middle left dining_table location center',
#  'person location middle right',
#  'vase location middle left toilet location middle right sink location middle left sink location top middle',
#  'cat location top middle car location middle left bottle location top left car location down middle',
#  'elephant location top left person location top middle',
#  'bird location center',
#  'stop_sign location middle right',
#  'person location center tennis_racket location center',
#  'zebra location center',
#  'sink location down left sink location middle left',
#  'bear location top middle',
#  '',
#  'giraffe location center',
#  'tv location down middle',
#  'broccoli location middle left broccoli location top middle carrot location center broccoli location down right carrot location down middle',
#  '',
#  'toilet location top middle',
#  'bowl location center broccoli location top right',
#  'toilet location down middle sink location down middle',
#  'cow location middle left person location center person location middle right person location middle right person location top left person location middle left person location middle left',
#  '',
#  'clock location top left clock location top middle',
#  '',
#  'fire_hydrant location middle left person location middle right person location middle right car location middle left',
#  'car location middle left',
#  'bus location center',
#  'couch location center cup location middle right couch location center',
#  'sandwich location top middle',
#  'train location middle left',
#  'teddy_bear location middle right',
#  'cat location middle left',
#  'clock location center',
#  'person location top middle elephant location top middle',
#  'bird location center',
#  'person location center sports_ball location center',
#  'person location top right person location center person location center dining_table location middle left couch location middle left',
#  '',
#  'person location middle right skis location middle right',
#  'person location center umbrella location top right person location top middle person location top right person location top left person location top left dog location center umbrella location top left',
#  'person location top right person location middle left',
#  '',
#  'person location center baseball_glove location middle right',
#  'elephant location down middle elephant location middle left',
#  'person location middle left',
#  'cat location center',
#  'bottle location top middle person location top left cup location middle right bottle location top middle',
#  'train location center',
#  'person location middle left',
#  'person location down middle person location down middle surfboard location down middle',
#  'elephant location center elephant location top middle',
#  '',
#  'person location middle left person location middle right person location center',
#  'person location middle left remote location center',
#  'traffic_light location middle left traffic_light location down left traffic_light location middle left',
#  'toilet location down left',
#  'donut location down left donut location down middle donut location middle left',
#  'teddy_bear location center',
#  'person location center person location top left truck location middle right person location middle left person location middle left person location middle left person location middle left',
#  '',
#  'bed location top left',
#  'microwave location top middle oven location top middle',
#  'person location middle left',
#  'toilet location down left person location top left person location middle left',
#  'zebra location middle left zebra location down left zebra location middle right',
#  'traffic_light location middle right',
#  'airplane location center',
#  'person location middle left person location middle left',
#  'person location middle right person location middle left',
#  'elephant location center elephant location middle left elephant location top middle',
#  'airplane location middle left',
#  'truck location center',
#  'sink location down left',
#  'bear location top middle',
#  'orange location center orange location down right orange location down right bowl location down middle vase location center',
#  'car location top middle',
#  'car location down middle',
#  'clock location top middle',
#  'person location top middle person location down middle skateboard location down middle skateboard location middle left',
#  'stop_sign location center',
#  'bicycle location center person location center motorcycle location middle left person location middle left bicycle location middle left',
#  '',
#  'sink location center sink location top left',
#  'person location center car location middle right car location down left person location middle left car location middle left car location top left traffic_light location top left bicycle location middle right',
#  'person location top middle skateboard location down left',
#  'person location top left bottle location center tennis_racket location top left',
#  'bench location top middle',
#  'suitcase location center',
#  'giraffe location center giraffe location top left',
#  'cat location center laptop location middle left',
#  'cell_phone location middle left person location middle left',
#  '',
#  'dog location top middle horse location middle left person location middle left',
#  'zebra location center',
#  'teddy_bear location top middle teddy_bear location center',
#  'banana location center apple location middle right apple location middle right apple location down right apple location down middle',
#  'person location middle right pizza location down middle person location center bottle location middle left pizza location middle left pizza location middle left knife location middle left person location center cup location center cup location middle left',
#  'clock location top middle',
#  'person location top middle',
#  'motorcycle location down left',
#  'banana location center',
#  'person location middle right bus location top left person location center bus location top left person location middle left person location top right person location top left person location center',
#  'person location center person location center person location middle left person location middle left person location down right person location center person location middle left person location center person location middle right',
#  'person location top left person location top left person location top left person location top middle',
#  'train location middle left',
#  'suitcase location center suitcase location top left chair location top right person location top middle suitcase location down middle',
#  'person location center person location center person location down right potted_plant location center person location middle left book location down left couch location top middle',
#  'laptop location top middle cat location center',
#  'person location center surfboard location middle left',
#  'car location down left car location down right car location down middle car location down left traffic_light location top middle traffic_light location top middle',
#  'person location middle left person location top middle kite location top left',
#  '',
#  'knife location center carrot location middle left',
#  'pizza location middle left wine_glass location top middle bottle location top middle bottle location top middle bottle location top middle bottle location top right cup location top middle cup location top middle',
#  'bowl location center dining_table location center',
#  'boat location middle left person location center',
#  '',
#  'zebra location top left zebra location top left',
#  'cat location center bed location center',
#  'suitcase location middle left person location top left person location middle left handbag location down right',
#  'person location center',
#  'bear location down right',
#  'person location middle left cake location down left dining_table location down middle',
#  'person location down left person location top middle person location center person location center person location top left person location middle left person location middle right person location middle right person location center person location top right',
#  'dog location middle left person location middle left',
#  'zebra location middle left zebra location middle left zebra location middle right',
#  'person location center',
#  'person location down middle',
#  'person location center tennis_racket location center',
#  'person location middle left bottle location middle right cat location top left bottle location center',
#  'toilet location middle left',
#  '',
#  'horse location middle left horse location center',
#  'sandwich location center person location middle left',
#  '',
#  'cat location down middle',
#  'cow location top middle',
#  'person location center skis location down left',
#  'cow location middle right cow location center cow location middle right cow location middle right',
#  'person location center person location top left person location top middle',
#  'cat location center tv location top left cat location center',
#  'laptop location center person location middle left',
#  'person location down middle person location down middle person location down right sports_ball location top middle baseball_glove location down middle',
#  'banana location top left orange location center apple location top right orange location top left',
#  'person location center bicycle location center',
#  'elephant location down left elephant location down middle elephant location middle right elephant location top middle person location down left person location down right person location center person location down left person location down middle',
#  'cake location top left fork location middle left cake location center',
#  'laptop location top left',
#  'person location center car location top left car location top left',
#  'person location middle left person location top right tennis_racket location middle right person location top middle',
#  'person location top middle person location top right person location top right',
#  'clock location top left',
#  'clock location center',
#  'sheep location center',
#  'cup location top left bottle location down left cup location top right',
#  'cup location top middle bottle location top left sandwich location center bowl location middle left dining_table location middle left',
#  'person location middle left horse location down left person location center person location center',
#  '',
#  'person location middle right person location middle left person location middle left person location top left person location middle left person location top middle',
#  'horse location middle right person location middle left person location center',
#  'umbrella location top middle person location top middle person location top left person location center person location top middle person location top middle',
#  '',
#  'bench location middle left bench location down left car location middle right',
#  'tv location top left',
#  'bird location top middle',
#  'person location center surfboard location down middle',
#  'person location center person location middle left person location top middle person location top right tennis_racket location down middle person location top left',
#  'umbrella location top middle person location center',
#  'car location down middle car location down left person location down left person location middle left car location down middle motorcycle location down left',
#  'person location middle left person location center skateboard location middle left',
#  'bus location center',
#  'person location center',
#  'stop_sign location top middle',
#  'person location middle left',
#  'bird location down middle bird location middle left',
#  'person location middle left person location middle left person location top left person location down right person location middle right person location top left person location middle right person location center person location top left cup location middle left person location center',
#  'zebra location center',
#  'truck location center',
#  'person location top left person location down right baseball_glove location center person location down left baseball_bat location top middle',
#  'pizza location center broccoli location middle left broccoli location top left broccoli location top middle',
#  'person location center',
#  'bird location top left bird location top left bird location center',
#  'person location top left person location top middle person location middle right person location middle right person location top middle dining_table location middle left book location center',
#  'train location middle right',
#  'person location center',
#  'cow location center',
#  'chair location middle left couch location center suitcase location center',
#  'bus location down middle car location down left car location middle right car location middle left car location down right car location down left car location middle right traffic_light location middle right car location down right',
#  'zebra location center',
#  'teddy_bear location center book location top right teddy_bear location middle left book location top right teddy_bear location top left teddy_bear location down middle',
#  'cow location center cow location middle left',
#  'person location top left person location top right chair location middle left dining_table location down middle person location center chair location middle right',
#  'zebra location top left',
#  '',
#  'person location center',
#  'dog location middle left dog location top left',
#  'person location center skateboard location down middle',
#  'clock location top left bicycle location center person location down middle truck location down middle person location down left person location down left bus location down left person location down left',
#  'cup location middle right cup location center pizza location top middle cup location top right cup location top middle dining_table location top left pizza location top middle pizza location top middle pizza location top middle pizza location top middle person location top left',
#  'potted_plant location middle right chair location center couch location top left potted_plant location middle right',
#  'bear location middle left cow location down left',
#  'cat location top left',
#  'person location center person location middle left person location center banana location center person location center banana location center',
#  '',
#  'bird location top left boat location center person location down right person location down middle person location down right',
#  '',
#  'person location center tennis_racket location middle left person location top left person location top right person location top middle',
#  'elephant location center elephant location center',
#  'person location top left person location middle left person location top left',
#  'person location down left person location center person location top right person location top right person location top right person location top left baseball_glove location center person location top middle',
#  'stop_sign location center car location down right car location middle left car location middle left car location down middle car location middle right car location middle left car location middle left',
#  'banana location top left remote location middle right',
#  'person location middle right person location down middle person location down right person location middle left person location down left person location top middle person location middle left person location center person location top middle person location middle left person location center',
#  'person location middle right person location top middle handbag location down right person location middle left person location middle left',
#  'car location down left car location down left car location down left person location middle left',
#  'bird location top middle',
#  'potted_plant location top middle refrigerator location down left oven location down left',
#  'person location center person location center frisbee location top right',
#  'person location top middle person location top left person location center person location top right',
#  'person location top middle person location top middle bowl location down middle cup location top middle person location top left cup location middle left dining_table location top left person location middle left wine_glass location center bottle location top right cup location middle right',
#  'pizza location middle left',
#  'person location top left horse location middle left person location center',
#  'bowl location center',
#  'surfboard location center surfboard location middle left surfboard location center surfboard location middle right surfboard location middle left surfboard location center surfboard location middle right surfboard location middle left surfboard location middle right',
#  'person location center sports_ball location middle right',
#  '',
#  'person location center suitcase location center',
#  'bear location middle left bear location middle left',
#  'person location middle left tv location center',
#  'bus location top middle car location top left',
#  'person location middle left',
#  'couch location center tv location center chair location down left couch location down left',
#  'person location down middle person location center person location center person location middle right bus location middle left person location middle right person location center',
#  'person location top left person location top middle cake location down middle cake location down middle cup location top left cake location middle right',
#  'orange location down left orange location center orange location middle right orange location center',
#  'person location center frisbee location down left',
#  '',
#  'kite location top left surfboard location center person location down left person location middle left',
#  'person location top middle skateboard location top middle',
#  'person location middle left person location center person location middle right',
#  'zebra location middle right zebra location middle left zebra location middle right zebra location middle left zebra location center zebra location center zebra location center',
#  'parking_meter location middle left parking_meter location top left',
#  '',
#  'bench location down right train location middle left',
#  'toilet location down middle',
#  'cow location middle right cow location center horse location middle left cow location center cow location middle left horse location middle left',
#  'person location top middle person location center person location top middle',
#  'person location top middle',
#  'person location center sheep location down middle sheep location middle right sheep location down right sheep location down right sheep location down right',
#  'person location top middle',
#  'person location center person location center person location center baseball_bat location top middle baseball_glove location middle left',
#  'dining_table location middle left',
#  'car location down middle bicycle location center',
#  'clock location top right',
#  'train location center',
#  'baseball_glove location center person location center',
#  'person location top middle kite location top left',
#  'person location top middle giraffe location middle right',
#  'carrot location middle right carrot location top middle',
#  'person location center person location down middle person location top middle person location middle left person location down middle person location middle left car location middle left frisbee location top middle person location middle right person location middle right',
#  'person location top left person location top middle person location top left person location top middle',
#  'cat location top left tv location center',
#  'laptop location top left tv location middle left mouse location down middle cup location middle left keyboard location down middle cup location center chair location middle right',
#  'cat location middle left',
#  'pizza location top left',
#  'airplane location down middle',
#  'clock location center',
#  'person location top left tie location top middle',
#  'person location center',
#  'person location middle right motorcycle location middle left',
#  'tie location center cat location center',
#  'skateboard location down middle person location center',
#  'dining_table location top left broccoli location top right broccoli location center bowl location top left',
#  'bottle location top left bottle location top right bottle location top left bottle location top middle',
#  'vase location top left vase location down middle',
#  'horse location middle right horse location center person location middle left',
#  'person location middle left person location middle right person location center sports_ball location top middle person location center',
#  'person location middle left person location top right bottle location middle left',
#  'bear location top middle',
#  'person location center skateboard location center',
#  'person location center person location middle right elephant location down middle person location middle left',
#  'frisbee location middle left frisbee location center frisbee location middle left frisbee location middle left person location center person location top left person location center person location center',
#  'person location middle left person location center',
#  'train location down left',
#  'traffic_light location top middle traffic_light location middle left traffic_light location top right',
#  '',
#  'person location middle left person location top left person location top left person location top right person location top left backpack location middle left tennis_racket location down middle person location top left person location top right',
#  'person location top middle',
#  'person location center tennis_racket location down middle',
#  'airplane location middle left',
#  'person location down left train location center',
#  'elephant location middle left',
#  'bench location down right boat location center',
#  'cow location center cow location middle left',
#  'bus location center traffic_light location middle left person location top left person location middle left person location middle left',
#  'person location center person location middle left person location center person location down left person location center person location center person location center person location middle right person location center person location center person location middle left baseball_glove location middle right',
#  'horse location middle right cow location top left',
#  'cat location top left',
#  'laptop location center bed location center',
#  'kite location top right person location down left person location down left person location middle left person location down middle',
#  'giraffe location center',
#  'train location top left',
#  'person location down left',
#  'bed location down middle cat location center',
#  'airplane location center person location down right',
#  '',
#  'car location middle left parking_meter location middle left car location top middle person location center car location middle left',
#  'person location top middle person location top right bench location top middle skateboard location middle right',
#  'refrigerator location center toaster location down left',
#  'sports_ball location down right person location middle right',
#  'bicycle location middle left',
#  'airplane location center airplane location center airplane location center',
#  'chair location middle right laptop location center keyboard location center tv location top middle cup location center',
#  'clock location top left clock location top left',
#  'train location center train location center',
#  'cake location center',
#  'sink location down middle',
#  'person location down left',
#  'vase location top middle chair location down left dining_table location down middle potted_plant location center refrigerator location middle left chair location center potted_plant location top right',
#  'oven location center',
#  'laptop location down left person location top middle chair location middle right laptop location top left person location top right chair location top middle person location center chair location middle right cup location down left dining_table location middle right',
#  'laptop location top middle cup location down right cup location down right',
#  'person location middle left bowl location down middle person location top left',
#  'person location center person location middle left motorcycle location center motorcycle location center person location top right',
#  'bowl location center',
#  'person location middle left person location center person location down middle',
#  '',
#  'person location middle right person location center umbrella location top middle motorcycle location middle left pizza location down middle potted_plant location down right',
#  'person location top right person location top left person location center person location middle left bottle location middle right bottle location top right couch location middle left',
#  'person location down left',
#  'cow location top left',
#  'train location center car location down left train location center',
#  'person location down middle kite location middle left',
#  'airplane location top middle',
#  'person location top left orange location down middle',
#  'pizza location middle left dining_table location middle left',
#  'frisbee location top middle dog location center',
#  'fire_hydrant location top middle',
#  'bicycle location down left person location center person location down middle person location down left car location down middle potted_plant location down left car location down right',
#  'sink location top middle toilet location middle right',
#  'oven location top left cake location center',
#  'dining_table location center orange location top middle',
#  'bus location center person location down left person location middle left person location center',
#  'tv location middle left chair location center person location top right chair location center',
#  'person location middle left tv location top right',
#  'person location center person location middle left person location center person location middle right person location top left person location center person location top left person location top middle',
#  'tv location center couch location middle left chair location down middle chair location middle right chair location down right vase location down middle dining_table location down middle',
#  'cake location center banana location middle left',
#  'tv location center chair location down right chair location middle left couch location down left book location center',
#  'airplane location center',
#  'dog location center frisbee location down right',
#  '',
#  'suitcase location down right',
#  'dining_table location center chair location middle right bottle location middle left vase location down middle chair location down left chair location center',
#  'person location top right bus location middle left person location middle left',
#  'horse location center person location top middle',
#  'horse location down left person location middle right',
#  'refrigerator location down left',
#  '',
#  'vase location down middle',
#  'fire_hydrant location top middle person location top right person location center person location middle left',
#  'sheep location middle right sheep location down right sheep location down middle person location middle left',
#  'person location center person location middle right person location center cake location middle right cake location middle right',
#  'clock location top left',
#  'kite location down middle kite location down middle kite location center kite location center person location center',
#  'clock location middle left',
#  'pizza location center cup location center person location center cup location middle left dining_table location middle left person location middle right cup location middle left',
#  'broccoli location top middle carrot location top middle',
#  'car location down right car location down right',
#  'motorcycle location down middle',
#  'pizza location center bottle location top middle bowl location top left dining_table location top middle person location top middle',
#  'pizza location center',
#  'person location down left person location center person location down middle person location middle left person location down left person location down right person location down right person location middle right person location center person location down left person location center person location center person location down middle person location top right',
#  'laptop location center person location center',
#  'person location middle left person location top left person location middle left person location middle right person location top middle motorcycle location center bicycle location down middle person location middle left',
#  'car location down middle bus location down left car location down right car location down right car location down middle',
#  'bowl location center',
#  'car location down right',
#  'person location middle right bowl location down left cup location middle left cup location down middle',
#  'person location middle left person location middle right',
#  'person location center person location center surfboard location center person location middle right person location middle left',
#  'person location top right kite location top middle person location top right person location center kite location down middle',
#  'person location middle left motorcycle location down left motorcycle location center',
#  'person location center person location down right person location down left tennis_racket location middle left person location top middle person location top middle',
#  'train location down left',
#  'bus location top middle',
#  'umbrella location middle right person location down left person location down middle person location middle left person location center person location top left person location down right person location down middle person location top left person location top middle',
#  '',
#  'person location top middle person location top middle person location middle left',
#  'airplane location down middle',
#  'motorcycle location center person location top middle person location middle right',
#  'person location center bicycle location down middle car location top right car location top left',
#  'person location middle right person location top middle person location top left person location middle right person location top left person location top middle kite location center person location top middle person location top left person location top middle',
#  'car location down middle traffic_light location top middle',
#  'train location top middle person location down middle person location middle left',
#  'person location center',
#  'toilet location middle left cup location top middle',
#  'boat location middle right',
#  'person location top middle remote location down left',
#  'teddy_bear location center person location down left',
#  'clock location center',
#  'person location top right person location top middle person location top left',
#  'motorcycle location center person location center person location top middle person location top right',
#  'person location middle left skateboard location center',
#  'dog location center',
#  'person location top left person location top left bottle location top right',
#  'person location top middle person location center cake location middle left dining_table location down left person location top middle',
#  'chair location down middle umbrella location middle right',
#  'person location top middle person location middle left pizza location top right pizza location middle left bowl location middle left bottle location top right',
#  'wine_glass location middle left bottle location center pizza location top middle',
#  '',
#  'person location top middle motorcycle location center person location top middle person location top left person location top left person location top left person location top right car location top middle person location top left person location top right',
#  'train location top middle person location middle left person location middle left',
#  'person location down left person location center skateboard location down middle',
#  'cake location top left dining_table location center',
#  'car location middle left car location middle left bus location center car location top middle',
#  'fire_hydrant location top middle truck location top left truck location top left',
#  'laptop location down left person location top left laptop location down left chair location top left',
#  '',
#  'toilet location center',
#  'bus location middle left car location center car location middle left car location middle right',
#  'person location top left person location top left person location middle left cell_phone location center',
#  'person location top middle person location middle left person location top middle person location middle left person location middle left',
#  'truck location middle left truck location middle right',
#  '',
#  'bus location center person location down middle person location down middle person location middle left person location middle left person location down right person location middle right',
#  'laptop location middle left keyboard location down middle tv location center mouse location down middle tv location middle right',
#  'person location top left person location top left',
#  'apple location top middle',
#  'truck location center truck location middle left truck location top right',
#  '',
#  'person location middle left surfboard location middle left',
#  'zebra location center',
#  'elephant location center cow location middle left',
#  'donut location middle left donut location middle left donut location top right donut location down right donut location top middle donut location down left',
#  'person location middle right person location middle right',
#  'person location center',
#  'tv location middle left mouse location down right keyboard location down middle bottle location center mouse location down right',
#  'person location center skateboard location down middle person location middle left person location center',
#  'motorcycle location down middle',
#  'person location top middle dog location center',
#  '',
#  'person location center',
#  'person location down middle chair location down right umbrella location middle left bottle location down middle',
#  'person location center fire_hydrant location middle right person location middle left person location top left person location top left',
#  'tv location top middle laptop location down left mouse location down left keyboard location down middle',
#  'cup location top right person location center person location top middle refrigerator location top middle cup location center cake location down middle',
#  'bottle location center cup location center bottle location middle right cup location middle right person location top middle person location top right',
#  'person location top middle person location top left person location down left person location top right person location down left skateboard location middle left',
#  'giraffe location center giraffe location center',
#  'cake location top middle sandwich location middle left',
#  'clock location center',
#  'person location center person location middle right person location top right bicycle location middle right',
#  'person location middle left',
#  'person location center person location middle left person location middle left person location middle left person location center person location top right person location top right',
#  'bird location center',
#  'person location top middle person location middle left person location down left tennis_racket location center',
#  'person location top left person location top right tie location center',
#  'giraffe location down middle',
#  'chair location down left person location center person location middle left person location middle left chair location down middle chair location down right person location middle left chair location down left person location middle right person location middle right person location middle right cup location middle left dining_table location center',
#  'train location center',
#  'cup location down middle person location middle right person location top left person location top middle',
#  'car location top middle dog location center',
#  'motorcycle location middle left person location center',
#  'tie location center person location top left',
#  'fire_hydrant location middle right',
#  'bowl location middle right bowl location top right bowl location middle left bowl location top middle carrot location top right',
#  'person location center person location middle left tennis_racket location top middle',
#  '',
#  'cow location center cow location down right cow location middle left cow location center cow location center cow location down middle cow location middle left cow location center cow location center cow location center cow location middle right cow location middle left cow location center cow location top left cow location middle left',
#  'bicycle location down left',
#  'broccoli location center broccoli location middle left',
#  'giraffe location center giraffe location center',
#  'bus location center person location middle right person location top left person location top middle car location center person location middle right car location top middle chair location down left',
#  'car location middle left car location center car location down right truck location down left car location down middle',
#  'motorcycle location center',
#  'person location center person location top middle person location middle left person location center person location middle left person location middle right frisbee location top left',
#  'giraffe location center giraffe location down middle',
#  'teddy_bear location middle left teddy_bear location middle right',
#  'person location top left cup location center person location top right person location top middle person location middle left',
#  'car location middle left',
#  '',
#  'bench location middle left',
#  'suitcase location center person location top left backpack location center person location middle left suitcase location down middle person location top left person location middle right handbag location middle left',
#  '',
#  'knife location top left cake location center bowl location top left dining_table location middle left fork location middle left',
#  'person location middle right person location top left baseball_glove location center person location top middle person location center person location top middle person location center person location top left person location middle right baseball_bat location top middle',
#  'clock location middle left',
#  'person location middle right sports_ball location top left',
#  'truck location center',
#  'person location middle left person location middle left person location center person location top left person location center person location top left',
#  'person location down left person location down middle person location down left person location down left',
#  'scissors location top middle dining_table location top left',
#  '',
#  'vase location middle right chair location center potted_plant location center chair location middle left',
#  'stop_sign location top middle car location center',
#  'person location center',
#  'tv location top left vase location center',
#  'person location middle left',
#  'keyboard location center tv location center mouse location down right keyboard location center laptop location center',
#  'toilet location center',
#  'sheep location down middle',
#  'cat location center',
#  'clock location top right sports_ball location middle left',
#  'person location middle left boat location top middle person location center',
#  'sink location middle left',
#  'bus location down left bus location down middle',
#  'cake location center',
#  'cat location center',
#  'truck location middle left car location center truck location middle right person location middle left',
#  'train location center train location center',
#  'traffic_light location top right',
#  'elephant location center',
#  'person location top left skateboard location top middle',
#  'person location middle right person location center person location top middle person location middle left person location middle right',
#  'person location top left person location top right person location top left bottle location top middle pizza location down middle cup location middle right pizza location center pizza location down middle dining_table location center cup location center',
#  'bowl location down middle dining_table location top middle bowl location down left bowl location down middle clock location top right',
#  'clock location center person location down middle clock location middle left clock location middle left clock location middle right clock location top left person location middle right',
#  'chair location down left',
#  'kite location top left kite location top middle person location down left',
#  'person location center cup location down right cake location down middle person location top middle person location center',
#  'person location middle left person location center',
#  '',
#  'giraffe location center giraffe location middle left giraffe location center',
#  'sink location middle left',
#  'cake location top middle',
#  'elephant location center',
#  'person location center car location top left car location top middle skateboard location down middle car location top left car location top middle',
#  'carrot location top right broccoli location middle left broccoli location top middle bowl location middle left carrot location center carrot location top left broccoli location center',
#  'bowl location top left sandwich location top middle cup location middle left bottle location top left sandwich location down middle',
#  'fire_hydrant location center',
#  'bird location down middle',
#  'cup location down middle person location center cup location top middle',
#  'clock location top middle person location down left person location center person location middle left',
#  'person location center person location down left person location down left person location middle left person location center person location down right person location center person location top left dining_table location center',
#  'cat location center toilet location down middle sink location center',
#  'train location center',
#  'person location middle left car location top middle',
#  'person location center',
#  'bus location center bus location center bus location middle right person location middle left person location middle left person location middle left',
#  'person location center person location center dog location middle left car location middle right',
#  'bowl location top middle apple location center bowl location middle left person location top middle apple location middle right',
#  'person location center car location top middle handbag location center',
#  'elephant location center person location top left',
#  'person location center cake location down middle',
#  'pizza location middle left orange location top left',
#  'vase location down middle',
#  'zebra location middle left',
#  'person location down left kite location top left person location down right person location down right',
#  'bed location top left cat location center',
#  'horse location middle left person location middle left',
#  'train location center clock location top left',
#  'refrigerator location top middle',
#  'giraffe location middle right zebra location center',
#  'pizza location down middle pizza location top right car location top right bottle location middle left person location top middle car location top right',
#  'zebra location top left sheep location middle left sheep location middle left',
#  'keyboard location down middle person location center tv location middle left cup location center',
#  '',
#  'person location down middle person location down middle boat location center boat location down left',
#  'boat location center',
#  'person location center person location middle left person location middle right person location down left person location top right baseball_glove location middle left baseball_bat location top middle baseball_glove location middle left person location top middle',
#  '',
#  'person location middle right umbrella location top middle',
#  'airplane location middle left airplane location center',
#  'car location down left car location down right',
#  'vase location down left',
#  'person location middle left person location middle left dog location center',
#  'clock location middle left',
#  'person location center skis location down middle',
#  'person location middle left person location middle right person location middle left',
#  '',
#  'person location center tennis_racket location center',
#  'person location center',
#  'person location top left',
#  'person location top left person location top right pizza location center',
#  'person location down left person location top right person location middle left person location top middle person location down left person location center skateboard location top middle skateboard location down middle person location top right skateboard location middle right person location top left skateboard location middle left person location middle right person location down left person location down right person location middle right skateboard location middle left skateboard location middle left person location top middle skateboard location down middle skateboard location top right skateboard location center',
#  'person location middle left teddy_bear location down right',
#  'person location top left person location top left person location top right person location top left person location top middle person location top middle',
#  'bench location center',
#  'horse location top right person location middle right person location center person location top left',
#  '',
# ...
#  'sheep location down middle sheep location center person location center sheep location middle right person location middle left sheep location down right sheep location down right',
#  'chair location down left chair location down left potted_plant location top middle couch location down left couch location down right',
#  'wine_glass location top left dining_table location top left cup location top middle spoon location top middle',
#  'zebra location top left',
#  'person location center car location top left bench location center potted_plant location top left potted_plant location top left',
#  'cat location center',
#  'person location center',
#  '',
#  'person location center person location down left',
#  'person location center person location middle left',
#  'couch location middle left',
#  'laptop location middle left suitcase location middle left',
#  'spoon location middle right cup location top middle cake location center dining_table location top middle bowl location center',
#  'person location down left bird location down right',
#  'bowl location middle right person location center person location center bowl location down middle',
#  'person location center',
#  'person location center person location top right person location top left person location top left',
#  'book location top left book location top middle',
#  '',
#  'person location center surfboard location middle left',
#  'traffic_light location center traffic_light location top middle traffic_light location top right truck location center traffic_light location top right traffic_light location top middle traffic_light location center',
#  'person location center person location top middle person location center tennis_racket location top left',
#  'elephant location down left person location center person location center person location center',
#  'airplane location center',
#  'person location down middle person location down left person location down middle elephant location center',
#  'person location middle right horse location center',
#  'person location top middle person location top middle car location middle left car location middle right car location middle right traffic_light location top middle person location center person location center traffic_light location top middle person location middle left person location center',
#  'person location center person location middle right tie location down right tie location top left',
#  'person location down left person location center person location middle right cup location down right cup location center person location middle right wine_glass location down left dining_table location down middle wine_glass location down middle person location top middle person location middle right person location top middle person location center bowl location center cup location down middle cup location center person location down left person location top middle person location middle left person location top middle',
#  'sandwich location center donut location down middle bowl location center',
#  'train location center',
#  'person location down left person location top left person location center person location middle left person location middle right person location top left person location down right truck location middle left car location center person location top left car location middle left',
#  'truck location center',
#  'cup location top left cup location center cup location middle left sandwich location top left',
#  'train location center',
#  'person location middle left person location middle right person location middle left person location center person location top left car location top right',
#  '',
#  'vase location center bowl location middle left orange location center',
#  'person location middle left person location top middle person location center person location top middle person location center person location top left baseball_glove location top left person location top left',
#  'person location middle left',
#  '',
#  'person location center',
#  'dog location down left person location center frisbee location top middle sports_ball location top middle',
#  'person location down middle',
#  'zebra location middle left zebra location middle right zebra location middle left zebra location center zebra location middle right',
#  'person location middle right train location middle right bicycle location middle right person location center',
#  'horse location top right person location center horse location center',
#  'orange location middle left orange location top middle orange location top left orange location top left',
#  'dining_table location top left cup location top middle orange location middle right',
#  'banana location middle left',
#  'person location middle left person location middle right person location top left person location top middle',
#  'person location center person location top middle person location top left',
#  'person location top left',
#  'tv location middle left mouse location down right keyboard location down middle',
#  'cat location center',
#  'kite location top left kite location middle left kite location center kite location middle left kite location top middle kite location top left kite location top middle',
#  'bear location top middle bird location down right',
#  'person location center person location top middle person location top right person location top left person location top middle',
#  'train location middle left person location down left',
#  'cup location down left dining_table location middle left tv location middle left',
#  'giraffe location center',
#  'person location middle left person location center boat location center person location center person location center',
#  'orange location center orange location down right',
#  'bird location center',
#  'refrigerator location middle left chair location top left dining_table location top middle',
#  'person location center person location top middle sports_ball location middle right',
#  'bus location middle left person location center bus location center person location center person location middle right person location middle right person location middle right person location middle right',
#  'cat location top left person location top left cat location top middle',
#  'toilet location top right person location top middle',
#  'dog location center tv location middle left potted_plant location middle left',
#  'refrigerator location center',
#  'person location middle left surfboard location center',
#  'motorcycle location middle right',
#  'toilet location middle left toilet location middle left sink location down left',
#  'person location center skateboard location middle left',
#  'person location middle left tie location top middle',
#  'person location middle left person location middle left',
#  'airplane location center',
#  'person location center',
#  'person location middle left person location center person location middle right person location middle left person location middle left person location center',
#  'cat location top middle',
#  'person location top middle truck location top middle person location top middle bus location middle left',
#  'truck location center',
#  'person location down middle person location center person location center',
#  'person location top middle',
#  'boat location top middle',
#  'sandwich location middle left',
#  'orange location center banana location top left apple location top right',
#  'bench location center',
#  'fire_hydrant location down middle',
#  'chair location down left',
#  'teddy_bear location middle left',
#  'knife location top left cake location middle right',
#  'person location middle left person location center person location center bottle location middle left person location middle right person location top middle bottle location down left person location center cup location middle right bottle location center chair location top middle cup location down middle cup location center chair location center cup location down right cup location down right',
#  'car location down left',
#  'pizza location middle left cup location top right pizza location center knife location down middle person location top middle',
#  'person location center person location middle left person location top left',
#  'cat location center cat location middle right',
#  'chair location middle right keyboard location middle left keyboard location top middle cup location center mouse location down left tv location top right tv location top left tv location top middle tv location top left',
#  'airplane location top middle',
#  'person location middle left surfboard location center',
#  'dog location center boat location center person location center',
#  'laptop location middle right chair location center keyboard location top middle',
#  'person location center',
#  'bird location center',
#  'remote location middle left bed location top left person location center',
#  'bed location top left chair location top middle',
#  'person location center airplane location middle left person location center person location center person location middle right person location top middle person location center person location middle right',
#  'person location top middle bench location down middle person location down left bench location middle left person location center person location middle left suitcase location down middle',
#  'motorcycle location center person location top middle',
#  'person location top middle skateboard location middle left bench location middle left',
#  '',
#  'person location middle left person location top middle person location middle right person location middle right person location center',
#  'clock location center truck location down middle car location middle left car location down right',
#  'motorcycle location middle left motorcycle location down left motorcycle location down middle motorcycle location down left person location middle left motorcycle location center motorcycle location down middle motorcycle location down right motorcycle location center person location middle right',
#  'horse location center person location top middle',
#  'stop_sign location center',
#  'broccoli location center cup location top left dining_table location middle left fork location top right knife location center',
#  'horse location middle left horse location center person location center',
#  'person location middle right',
#  '',
#  'umbrella location down right umbrella location middle right umbrella location center umbrella location middle left person location down middle umbrella location top middle umbrella location top right person location down left umbrella location top left person location middle left umbrella location center umbrella location top left person location center person location top left umbrella location top middle person location down right umbrella location top middle person location top right person location top right',
#  'sink location top middle',
#  'pizza location down middle oven location center',
#  'broccoli location middle left person location top middle',
#  'person location top right car location down middle',
#  'person location middle left person location top left baseball_glove location down left sports_ball location middle right person location middle left person location middle right person location middle right',
#  'person location center person location down left',
#  'stop_sign location middle left car location center car location middle left truck location center',
#  'orange location down right bowl location down middle orange location middle left',
#  'dining_table location middle left cup location center donut location top middle cup location center spoon location center',
#  'person location top middle skateboard location top left',
#  'sheep location down left cow location center person location middle right',
#  'person location down right person location center person location top middle person location top left',
#  'person location down left person location center kite location top left person location center kite location top right person location middle right person location center person location center kite location top middle kite location top left person location center person location top right',
#  'person location top middle toothbrush location center',
#  'snowboard location down middle person location center',
#  'bed location down middle',
#  'person location middle right person location middle right surfboard location middle right',
#  'fire_hydrant location center person location top right car location middle right car location middle right',
#  'person location center',
#  'stop_sign location top middle',
#  'banana location top left',
#  'person location top right',
#  '',
#  'person location middle left tennis_racket location middle left sports_ball location top left chair location top middle',
#  'person location center skateboard location center',
#  'bear location center',
#  'cell_phone location center person location center person location middle right',
#  'bottle location top right pizza location down middle cup location center dining_table location top left cell_phone location top left bottle location top left',
#  'pizza location middle left',
#  'tv location top middle chair location down left bench location down left',
#  'person location center motorcycle location down left person location middle right person location center motorcycle location down middle bottle location top middle person location center bottle location top middle person location center bottle location top middle person location middle left person location center',
#  'bowl location middle left bowl location top right bowl location middle right cup location top left',
#  'bench location down right',
#  'bottle location center',
#  'tv location center couch location middle left',
#  'person location middle right tv location middle left clock location top right bowl location middle left',
#  'keyboard location down left laptop location center tv location center tv location middle left mouse location down left chair location middle left',
#  'carrot location middle left carrot location top left',
#  'person location down right person location center baseball_glove location center person location top left person location top right baseball_bat location middle left',
#  'airplane location center',
#  'kite location down middle skis location middle left person location down middle person location middle left',
#  'stop_sign location down middle',
#  'truck location center car location top left car location middle right',
#  'bus location middle left bicycle location middle left',
#  'sandwich location center',
#  'pizza location center pizza location middle left',
#  'person location middle left person location center person location top right person location center skis location down left person location center',
#  'vase location center',
#  'cat location center',
#  'person location top middle baseball_glove location down middle',
#  'sink location down middle bottle location top left',
#  'person location top right person location top middle',
#  'bird location top left person location center',
#  'person location center car location top left potted_plant location top left kite location down middle',
#  'train location middle left person location top middle',
#  'tv location middle left keyboard location middle left laptop location middle right tv location middle left cat location center',
#  'truck location down middle car location down left car location top left',
#  '',
#  'person location down middle traffic_light location middle right',
#  'sheep location center sheep location middle left sheep location top left',
#  'skateboard location down middle person location center',
#  'horse location center person location middle right person location middle left person location top left person location top right person location top left person location top right',
#  'person location top middle tie location center',
#  'bed location down right chair location down left dining_table location down left',
#  'person location top right tennis_racket location top left',
#  ...]

# %%
final_output[2:5]
# Out:
# ['car location middle left train location middle right',
#  'stop_sign location center car location down middle',
#  'person location top right person location center']

# %%
for i in range(len(final_output)):
    final_output[i]=final_output[i].replace("_"," ")
print(final_output)
# Out:
# ['person location top right person location top left person location middle left person location top middle person location center person location center person location center person location middle right person location top left person location down middle', 'frisbee location center person location top left person location top middle person location top right person location top right frisbee location top right frisbee location middle left', 'car location middle left train location middle right', 'stop sign location center car location down middle', 'person location top right person location center', 'bird location center', 'horse location center person location top left person location middle right', 'pizza location middle left', 'person location middle left person location center person location middle left person location top left cell phone location center', 'person location down middle person location down left person location middle left person location middle left person location center person location down right person location middle left person location down right', 'bed location center chair location middle right dining table location down middle', '', 'person location center baseball bat location top middle', 'couch location top left cat location top left', 'cat location top right bicycle location middle left', 'giraffe location middle right giraffe location middle left giraffe location middle left giraffe location middle left', 'airplane location center', 'car location down middle clock location top right', 'motorcycle location center person location center', 'motorcycle location top middle person location middle right', 'motorcycle location center person location middle left person location middle left person location center person location center person location middle left person location center person location center person location top middle', 'toilet location down left', 'cup location middle right', 'car location middle right person location middle left car location center', 'person location center cake location middle left dining table location center', 'person location middle right', 'vase location middle left toilet location middle right sink location middle left sink location top middle', 'cat location top middle car location middle left bottle location top left car location down middle', 'elephant location top left person location top middle', 'bird location center', 'stop sign location middle right', 'person location center tennis racket location center', 'zebra location center', 'sink location down left sink location middle left', 'bear location top middle', '', 'giraffe location center', 'tv location down middle', 'broccoli location middle left broccoli location top middle carrot location center broccoli location down right carrot location down middle', '', 'toilet location top middle', 'bowl location center broccoli location top right', 'toilet location down middle sink location down middle', 'cow location middle left person location center person location middle right person location middle right person location top left person location middle left person location middle left', '', 'clock location top left clock location top middle', '', 'fire hydrant location middle left person location middle right person location middle right car location middle left', 'car location middle left', 'bus location center', 'couch location center cup location middle right couch location center', 'sandwich location top middle', 'train location middle left', 'teddy bear location middle right', 'cat location middle left', 'clock location center', 'person location top middle elephant location top middle', 'bird location center', 'person location center sports ball location center', 'person location top right person location center person location center dining table location middle left couch location middle left', '', 'person location middle right skis location middle right', 'person location center umbrella location ...
